# %% [markdown]
# ## 時間情報のない集団データ

# %% [markdown]
# ### 方針

# %% [markdown]
# ・内部に問題ごとの依存関係を定義し、その関係をもとに遷移させる。
#
# ・条件付き確率（遷移確率）と周辺分布の積の和から次の周辺分布を求める。
#
# ・まずは遷移過程が部分的にしか分からない人工データを用意し、モデルを学習する。

# %% [markdown]
# ## 人工データ生成

# %%
import numpy as np

# 問題の依存関係の行列 A 
A = np.array([
    [0, 0, 0, 0, 0, 0],  # 初期状態
    [1, 0, 0, 0, 0, 0],  # 問題1は初期状態のみに依存
    [1, 0, 0, 0, 0, 0],  # 問題2は問題1に依存
    [0, 1, 1, 0, 0, 0],  # 問題3は問題2に依存
    [0, 0, 0, 1, 0, 0],  # 問題4は問題2、問題3に依存
    [0, 0, 0, 0, 1, 0]   # 問題4は問題2、問題3に依存
], dtype = float)*3

# 0でない要素の数で割る処理
nonzero_counts = np.count_nonzero(A[1:], axis=1, keepdims=True)
A[1:] = np.where(nonzero_counts != 0, A[1:] / nonzero_counts, 0)

# 遷移確率を計算する関数
def calculate_transition_probabilities(A, X):
    n = len(X)
    raw_probabilities = np.zeros(n)  # 遷移確率の元となる値
    
    # 不正解の問題に対して遷移確率を計算
    for i in range(n):
        if X[i] == 0:  # まだ正解していない問題のみ対象
            required_problems = A[i, :]  # i番目の問題に必要な依存関係
            
            solved_problems = X * required_problems  # 現状解けている
            
            num_solved = np.sum(solved_problems)      # 実際に解けた問題の数
            
            raw_probabilities[i] = np.exp(num_solved)
    
    # 総和で割って正規化
    total_sum = np.sum(raw_probabilities)  # expの総和
    if total_sum > 0:  # 総和が0でなければ正規化
        probabilities = raw_probabilities / total_sum
    else:
        probabilities = raw_probabilities  # 総和が0ならそのまま
    
    return probabilities

# %%
# 教師データセットを生成する関数
def generate_training_data(A, initial_X, num_correct_problems, num_data_per_step):
    n = len(initial_X)  # 問題数
    dataset = []
    
    # 各ステップでデータを生成
    for i in range(1, num_correct_problems+1):  # 1問以上の正解を対象にする
        for j in range(num_data_per_step):  # 各ステップごとにデータ数
            X = initial_X.copy()  # 初期状態からスタート
            
            # i問正解させる
            for k in range(i):
                input_X = X.copy()    # 遷移前状態を保持
                probabilities = calculate_transition_probabilities(A, X)
                
                if np.sum(probabilities) > 0:  # 正規化された確率がある場合
                    # 確率に基づいて次に正解させる問題を選択
                    next_correct_problem = np.random.choice(n, p=probabilities)
                    X[next_correct_problem] = 1  # 選ばれた問題を正解に遷移させる
            
                # 初期状態と1ステップ後の状態の差分を教師データとして使用
                target_Y = (X - input_X).clip(min=0)  # 0から1に変わった部分のみを1、他は0
                
                # 初期状態（入力）と差分（教師データ）のペアを保存
                dataset.append((input_X.copy(), target_Y.copy()))  # (入力データ, 教師データ)
    
    return dataset

# %%
import torch

import itertools
from collections import defaultdict

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
def _bcsoftmax1d(x, budget):
    """Budget Constrained Softmax function for vector.

    Args:
        x (Tensor): input vector. shape: (n_outputs, )
        budget (Tensor): budget (constraint) vector. shape: (n_outputs, )

    Returns:
        y (Tensor): output probability vector. shape: (n_outputs, ). Satisfying the constraints y_i <= budget_i.
    
    """
    x = x - torch.max(x, dim=0)[0] # normalization to avoid numerical errors
    exp_x = torch.exp(x)
    # sorting
    _, indices = torch.sort(budget / exp_x, descending=False)
    exp_x = exp_x[indices]
    budget = budget[indices]
    # find K_B
    r = torch.flip(torch.cumsum(torch.flip(exp_x, dims=(0, )), dim=0), dims=(0, ))
    s = 1.0 - (torch.cumsum(budget, dim=0) - budget)
    z = r / s
    is_in_KB = torch.logical_and(
        (s - budget) > 0, exp_x / z > budget
    )
    # compute outputs
    s = 1 - torch.sum(budget * is_in_KB)
    r = torch.sum(exp_x * (~is_in_KB))
    y = torch.where(~is_in_KB, s * exp_x / r, budget)
    # undo sorting
    _, inv_indices = torch.sort(indices, descending=False)
    return y[inv_indices]


def _bcsoftmax1d_stable(x, budget):
    """Budget Constrained Softmax function for vector.
    This function is more numerically stable than `_bcsoftmax1d` by computing some values in log-scale.
    
    Args:
        x (Tensor): input vector. shape: (n_outputs, )
        budget (Tensor): budget (constraint) vector. shape: (n_outputs, )

    Returns:
        y (Tensor): output probability vector. shape: (n_outputs, ). Satisfying the constraints y_i <= budget_i.
    
    """
    # sorting
    _, indices = torch.sort(torch.log(budget) - x, descending=False)
    x = x[indices]
    budget = budget[indices]
    # find K_B
    log_r = torch.flip(torch.logcumsumexp(torch.flip(x, dims=(0, )), dim=0), dims=(0, ))
    s = 1.0 - (torch.cumsum(budget, dim=0) - budget)
    is_in_KB = torch.logical_or(
        budget == 0,
        torch.logical_and(
            s - budget > 0,
            x - log_r + torch.log(s) > torch.log(budget)
        )
    )
    # compute outputs
    exp_x = torch.exp(x - torch.max(torch.where(~is_in_KB, x, -torch.inf), dim=0)[0])
    s = 1 - torch.sum(budget * is_in_KB)
    r = torch.sum(exp_x * (~is_in_KB))
    y = torch.where(~is_in_KB, s * exp_x / r, budget)
    # undo sorting
    _, inv_indices = torch.sort(indices, descending=False)
    return y[inv_indices]


class BCSoftmax1d(torch.autograd.Function):
    """Autograd implementation of Budget Constrained Softmax function for vector.
    """
    generate_vmap_rule = True
    
    @staticmethod
    def forward(x, c):
        y = _bcsoftmax1d_stable(x, c)
        return y

    @staticmethod
    def setup_context(ctx, inputs, output):
        x, c = inputs
        is_in_KB = c == output
        ctx.save_for_backward(x, c, is_in_KB)
    
    @staticmethod
    def backward(ctx, grad_y):
        x, c, is_in_KB = ctx.saved_tensors
        exp_x = torch.exp(
            x - torch.max(torch.where(~is_in_KB, x, -torch.inf), dim=0)[0]
        )
        s = 1 - torch.sum(c * is_in_KB)
        r = torch.sum(exp_x * (~is_in_KB))
        
        # compute Jacobian
        Jx = torch.where(
            torch.outer(~is_in_KB, ~is_in_KB),
            torch.diag(~is_in_KB * exp_x) * r - torch.outer(exp_x, exp_x),
            0,
        )
        Jx *= torch.where(
            s > 0,
            s / (r * r),
            0
        )
        Jc = torch.where(
            torch.outer(~is_in_KB, is_in_KB),
            - exp_x[:, None] / r,
            1.0 * torch.diag(is_in_KB)
        )

        # print("s", s, "r", r)
        # print("勾配", torch.matmul(grad_y, Jx), torch.matmul(grad_y, Jc))
        assert not torch.isnan(torch.matmul(grad_y, Jx)).any(), "Jx contains NaN"
        assert not torch.isinf(torch.matmul(grad_y, Jx)).any(), "Jx contains Inf"
        assert not torch.isnan(torch.matmul(grad_y, Jc)).any(), "Jc contains NaN"
        assert not torch.isinf(torch.matmul(grad_y, Jc)).any(), "Jc contains Inf"

        # return vector-Jacobian product
        return torch.matmul(grad_y, Jx), torch.matmul(grad_y, Jc)

# %%
######### Use these functions! #########
bcsoftmax1d = BCSoftmax1d.apply

# データによってmodelを通す回数が違
# bcsoftmax2d = torch.vmap(BCSoftmax1d.apply) # input shape = (batch_size, n_classes)

# %%
class Model(nn.Module):
    def __init__(self, num_questions):
        super(Model, self).__init__()
        self.fc = nn.Linear(num_questions, num_questions, bias=False)  # 全結合層

    def forward(self, x, c):
        x = self.fc(x)  # 全結合層の適用
        x = bcsoftmax1d(x, c)
        return x

# %%
"評価指標"

def kl_divergence(p, q, epsilon=1e-10):
    """
    KLダイバージェンスを計算する関数（qが0の場合の無限大問題を回避）
    
    Parameters:
        p (numpy.ndarray): 真の確率分布
        q (numpy.ndarray): 予測確率分布
        epsilon (float): スムージングパラメータ（非常に小さい値）
    
    Returns:
        float: KLダイバージェンス
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)
    
    # pとqにスムージングを適用
    p = np.where(p == 0, epsilon, p)
    q = np.where(q == 0, epsilon, q)
    
    # KLダイバージェンスの計算
    return np.sum(p * np.log(p / q))

def hellinger_distance(p, q):
    """
    Hellinger距離を計算する関数

    Parameters:
        p (numpy.ndarray): 真の分布 [batch_size, num_classes]
        q (numpy.ndarray): 予測分布 [batch_size, num_classes]
    
    Returns:
        float: Hellinger距離の平均値
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)
    # Hellinger距離の計算式: H(p, q) = (1/√2) * ||√p - √q||_2
    sqrt_p = np.sqrt(p)
    sqrt_q = np.sqrt(q)
    distance = np.sqrt(np.sum((sqrt_p - sqrt_q) ** 2)) / np.sqrt(2)
    return np.mean(distance)

def jensen_shannon_divergence(p, q):
    """
    Jensen-Shannon divergence を計算する関数

    Parameters:
        p (numpy.ndarray): 真の分布 [batch_size, num_classes]
        q (numpy.ndarray): 予測分布 [batch_size, num_classes]
    
    Returns:
        float: Jensen-Shannon divergence の平均値
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)

    # 0 の値があると log(0) が発生するため、微小値を加える
    epsilon = 1e-12
    p = np.clip(p, epsilon, 1)
    q = np.clip(q, epsilon, 1)
    
    # 分布の平均 M
    m = 0.5 * (p + q)
    
    # Kullback-Leibler divergence の補助関数
    def kl(a, b):
        return np.sum(a * np.log(a / b))
    
    # JSD の計算: JSD(p || q) = 0.5 * (KL(p || M) + KL(q || M))
    jsd = 0.5 * (kl(p, m) + kl(q, m))
    
    # 各サンプルの平均を返す
    return np.mean(jsd)


def evaluate_model(r, p, q):
    """
    遷移確率の真値と予測値の類似性を評価する関数
    :param r: 各ノードの重み (np.array)
    :param p: 各ノードの真の遷移確率 (2D np.array: ノード数 x 遷移確率)
    :param q: 各ノードの予測遷移確率 (2D np.array: ノード数 x 遷移確率)
    :return: 評価指標 L
    """
    L = 0
    for k in range(len(r)):
        L += r[k] * kl_divergence(p[k], q[k])
    return L

# %%
# データセットの生成
num_questions = 5  # 問題数
num_data_per_step = 50     # 各ステップごとに生成するデータ数

num_epochs = 1500  # エポック数
alpha = 0.001 # 正則化パラメータ
early_stopping_patience = 10  # Early Stopping の patience

split_ratio = 0.8  # 学習データと検証データの分割比率

# %%
"実験結果を保存する外部ファイル"
import csv
from datetime import datetime

# 今日の日付を "YYYY-MM-DD" 形式で取得
today = datetime.now().strftime("%Y-%m-%d")

# ファイル名に日付を含める
results_csv = f"results_allpath_{today}_{num_questions}_{num_data_per_step}_{num_data_per_step}_{split_ratio}.csv"

# 初回にヘッダーを追加する
header = [
    "Iteration", 
    "KL_Model_allpath",
    "HD_Model_allpath",
    "JSD_Model_allpath",
]

try:
    with open(results_csv, "x", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(header)
except FileExistsError:
    pass  # ファイルが既に存在する場合は何もしない

# %%
for trial in range(20):
    print(f"Trial {trial + 1}")

    "データ生成"

    # 生徒の回答状況 X (1が正解、0が不正解)
    # 初期状態は全て不正解
    X_init = np.array([1, 0, 0, 0, 0, 0])

    training_data = generate_training_data(A, X_init, num_questions, num_data_per_step)
    train_X = [input_data for input_data, _ in training_data]
    train_Y = [target_data for _, target_data in training_data]

    
    # データをトレーニングと検証に分割（正解数のバランスが良くなるように分割）
    # 8:2に分割
    def split_balanced_data(train_X, train_Y, ratio=0.8):
        data_per_correct_count = defaultdict(list)
        for x, y in zip(train_X, train_Y):
            correct_count = sum(y)
            data_per_correct_count[correct_count].append((x, y))

        train_X_data, train_Y_data, val_X_data, val_Y_data = [], [], [], []
        for correct_count, data in data_per_correct_count.items():
            split_index = int(len(data) * ratio)
            train_data = data[:split_index]
            val_data = data[split_index:]
            train_X_data.extend([x for x, y in train_data])
            train_Y_data.extend([y for x, y in train_data])
            val_X_data.extend([x for x, y in val_data])
            val_Y_data.extend([y for x, y in val_data])

        return train_X_data, train_Y_data, val_X_data, val_Y_data

    train_X_data, train_Y_data, val_X_data, val_Y_data = split_balanced_data(train_X, train_Y, split_ratio)

    # PyTorch テンソルに変換
    train_X = torch.tensor(train_X_data, dtype=torch.float32)
    train_Y = torch.tensor(train_Y_data, dtype=torch.float32)
    val_X = torch.tensor(val_X_data, dtype=torch.float32)
    val_Y = torch.tensor(val_Y_data, dtype=torch.float32)

    "状態定義"

    # Generate states where the first digit is always 1
    states = [(1,) + state for state in itertools.product([0, 1], repeat=num_questions)]

    states = sorted(states, key=lambda state: sum(state))

    # Initialize the state counts
    state_counts = defaultdict(int)

    # Assuming 'dataset' is your list of student results
    for result, result2 in training_data:
        # print(result2)
        state_tuple = tuple(map(int, result + result2))  # Convert np.int64 to int
        state_counts[state_tuple] += 1  # Count only if the first digit is 1

    # Display the counts for each state
    for state in states:
        count = state_counts[state]
        formatted_state = list(state)  # Convert tuple to list for the desired format

    "モデル定義"
    # モデル、損失関数、最適化関数の設定
    model = Model(num_questions+1)  # 5問+初期状態の問題を扱うモデル
    criterion = nn.CrossEntropyLoss()  # クロスエントロピー損失
    optimizer = optim.Adam(model.parameters(), lr=0.01)

    "学習"
    best_val_loss = float('inf')
    early_stopping_counter = 0

    for epoch in range(num_epochs):
        model.train()  # モデルを訓練モードに
        optimizer.zero_grad()  # 勾配の初期化
        
        outputs = []  # 出力を保持するリスト
        # 各データに対して train_Y の値に基づいてループを実行
        for i, target in enumerate(train_Y):
            c = torch.ones(num_questions+1, dtype=torch.float32)
            output = train_X[i]  # 各 i 番目の入力データを使用
            output = output.view(-1)

            # もしcの和が1なら、rが0となるので対応
            if c.sum() <= 1:
                # print("aaaaaaaa")
                output = c
            else:
                output = model(output, c)  # 前回の出力を次のステップの入力として使用

            outputs.append(output)  # 最終的な出力を保存

        # outputs を適切な形に変換して損失計算（例えば torch.stack を使用）
        outputs = torch.stack(outputs)
        outputs = outputs.squeeze(1)

        # モデルの出力の確認
        assert not torch.isnan(outputs).any(), "Model output contains NaN"
        assert not torch.isinf(outputs).any(), "Model output contains Inf"

        # L1正則化項の計算
        l1_reg = torch.tensor(0.0, requires_grad=True)
        for param in model.parameters():
            l1_reg = l1_reg + torch.sum(torch.abs(param))

        # 損失の計算
        loss0 = criterion(outputs, train_Y)

        loss = loss0 + alpha * l1_reg  # L1正則化項を追加した損失

        # 損失の確認
        assert not torch.isnan(loss).any(), "Loss contains NaN"
        assert not torch.isinf(loss).any(), "Loss contains Inf"

        # バックプロパゲーションとパラメータの更新
        loss.backward()
        optimizer.step()

        # 検証フェーズ
        model.eval()  # モデルを評価モードに
        with torch.no_grad():
            val_outputs = []
            for i, target in enumerate(val_Y):
                c = torch.cat([torch.tensor([0.0]), torch.ones(num_questions, dtype=torch.float32)])
                output = val_X[i]  # 各 i 番目の入力データを使用
                output = output.view(-1)
                for _ in range(int(sum(target))):
                    if c.sum() <= 1:
                        output_0 = c
                    else:
                        output_0 = model(output, c)
                    output = output_0 + output
                    c = c - output_0
                val_outputs.append(output - val_X[i])

            val_outputs = torch.stack(val_outputs)
            val_outputs = val_outputs.squeeze(1)
            val_loss0 = criterion(val_outputs, val_Y)
            val_loss = val_loss0 + alpha * l1_reg

        # Early Stopping の処理
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stopping_counter = 0
        else:
            early_stopping_counter += 1

        if early_stopping_counter >= early_stopping_patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

        # 100エポックごとに損失を表示
        if (epoch+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {val_loss.item():.4f}')

    # 学習結果の確認
    print("Training complete!")

    "モデル評価"
    node_probabilities = defaultdict(float)
    start = (1,) + tuple(0 for _ in range(num_questions))
    node_probabilities[start] = 1

    # 機械学習モデルと簡易モデル
    KL = 0
    HD = 0
    JSD = 0

    for state in states:
        probabilities = calculate_transition_probabilities(A, np.array(state))

        # 最下層から頂点までのノードの分布を順に計算
        for i in range(num_questions + 1):
            if state[i] == 0:  # まだ解けていない問題
                # 遷移後の状態
                next_state = list(state)
                next_state[i] = 1
                next_state = tuple(next_state)
                node_probabilities[next_state] += probabilities[i] * node_probabilities[state]
        
        # budgetの計算
        c_g = torch.ones(num_questions+1, dtype=torch.float32)
        c_g = c_g - torch.tensor(state, dtype=torch.float32)

        # 状態とその予測分布
        state_tensor = torch.tensor(state, dtype=torch.float32)
        predicted_values = model(state_tensor, c_g)  # 予測値を計算

    # 評価指標の計算
        kl = node_probabilities[state] * kl_divergence(probabilities, predicted_values.detach())
        hd = node_probabilities[state] * hellinger_distance(probabilities, predicted_values.detach())
        jsd = node_probabilities[state] * jensen_shannon_divergence(probabilities, predicted_values.detach())
        # print(f"状態: {state}, ノード分布: {node_probabilities[state]:.3g}, KL: {kl:.3g}, HD: {hd:.3g}, JSD: {jsd:.3g}")
        # print(f"真の遷移確率: {probabilities}, 予測遷移確率: {predicted_values}")
        KL += kl
        HD += hd
        JSD += jsd


    # 試行ごとの指標をCSVに追記
    with open(results_csv, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([
            trial + 1,
            KL,
            HD,
            JSD
        ])

    print(f"Trial {trial + 1} completed. Results saved.")
# Out:
# Trial 1
# /var/folders/zg/773ptkr55z99zw26dvy19_v00000gn/T/ipykernel_29200/4066109522.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   train_X = torch.tensor(train_X_data, dtype=torch.float32)
# Epoch [100/1500], Loss: 1.5847, Validation Loss: 1.6192
# Epoch [200/1500], Loss: 1.4777, Validation Loss: 1.5377
# Epoch [300/1500], Loss: 1.4419, Validation Loss: 1.5104
# Epoch [400/1500], Loss: 1.4275, Validation Loss: 1.4985
# Epoch [500/1500], Loss: 1.4204, Validation Loss: 1.4880
# Early stopping at epoch 571
# Training complete!
# Trial 1 completed. Results saved.
# Trial 2
# Epoch [100/1500], Loss: 1.5969, Validation Loss: 1.6427
# Epoch [200/1500], Loss: 1.4918, Validation Loss: 1.5563
# Epoch [300/1500], Loss: 1.4535, Validation Loss: 1.5195
# Epoch [400/1500], Loss: 1.4382, Validation Loss: 1.5043
# Epoch [500/1500], Loss: 1.4309, Validation Loss: 1.4976
# Epoch [600/1500], Loss: 1.4266, Validation Loss: 1.4934
# Epoch [700/1500], Loss: 1.4238, Validation Loss: 1.4903
# Epoch [800/1500], Loss: 1.4219, Validation Loss: 1.4867
# Epoch [900/1500], Loss: 1.4200, Validation Loss: 1.4747
# Early stopping at epoch 960
# Training complete!
# Trial 2 completed. Results saved.
# Trial 3
# Epoch [100/1500], Loss: 1.5875, Validation Loss: 1.5890
# Epoch [200/1500], Loss: 1.4917, Validation Loss: 1.4914
# Epoch [300/1500], Loss: 1.4585, Validation Loss: 1.4550
# Epoch [400/1500], Loss: 1.4449, Validation Loss: 1.4393
# Epoch [500/1500], Loss: 1.4383, Validation Loss: 1.4320
# Epoch [600/1500], Loss: 1.4345, Validation Loss: 1.4273
# Epoch [700/1500], Loss: 1.4319, Validation Loss: 1.4234
# Epoch [800/1500], Loss: 1.4303, Validation Loss: 1.4203
# Epoch [900/1500], Loss: 1.4289, Validation Loss: 1.4162
# Epoch [1000/1500], Loss: 1.4172, Validation Loss: 1.3113
# Early stopping at epoch 1011
# Training complete!
# Trial 3 completed. Results saved.
# Trial 4
# Epoch [100/1500], Loss: 1.5930, Validation Loss: 1.5951
# Epoch [200/1500], Loss: 1.4903, Validation Loss: 1.4994
# Epoch [300/1500], Loss: 1.4457, Validation Loss: 1.3743
# Epoch [400/1500], Loss: 1.4282, Validation Loss: 1.3425
# Epoch [500/1500], Loss: 1.4201, Validation Loss: 1.3306
# Epoch [600/1500], Loss: 1.4153, Validation Loss: 1.3244
# Epoch [700/1500], Loss: 1.4121, Validation Loss: 1.3200
# Epoch [800/1500], Loss: 1.4098, Validation Loss: 1.3166
# Epoch [900/1500], Loss: 1.4082, Validation Loss: 1.3138
# Epoch [1000/1500], Loss: 1.4068, Validation Loss: 1.3115
# Epoch [1100/1500], Loss: 1.4058, Validation Loss: 1.3094
# Epoch [1200/1500], Loss: 1.4050, Validation Loss: 1.3079
# Early stopping at epoch 1276
# Training complete!
# Trial 4 completed. Results saved.
# Trial 5
# Epoch [100/1500], Loss: 1.5848, Validation Loss: 1.5701
# Epoch [200/1500], Loss: 1.4884, Validation Loss: 1.4235
# Epoch [300/1500], Loss: 1.4538, Validation Loss: 1.3724
# Epoch [400/1500], Loss: 1.4387, Validation Loss: 1.3502
# Epoch [500/1500], Loss: 1.4302, Validation Loss: 1.3373
# Epoch [600/1500], Loss: 1.4246, Validation Loss: 1.3292
# Epoch [700/1500], Loss: 1.4207, Validation Loss: 1.3231
# Epoch [800/1500], Loss: 1.4180, Validation Loss: 1.3194
# Epoch [900/1500], Loss: 1.4161, Validation Loss: 1.3171
# Epoch [1000/1500], Loss: 1.4148, Validation Loss: 1.3154
# Epoch [1100/1500], Loss: 1.4138, Validation Loss: 1.3139
# Epoch [1200/1500], Loss: 1.4131, Validation Loss: 1.3127
# Epoch [1300/1500], Loss: 1.4125, Validation Loss: 1.3119
# Epoch [1400/1500], Loss: 1.4121, Validation Loss: 1.3113
# Epoch [1500/1500], Loss: 1.4116, Validation Loss: 1.3108
# Training complete!
# Trial 5 completed. Results saved.
# Trial 6
# Epoch [100/1500], Loss: 1.6011, Validation Loss: 1.6119
# Epoch [200/1500], Loss: 1.5057, Validation Loss: 1.5360
# Epoch [300/1500], Loss: 1.4743, Validation Loss: 1.5101
# Epoch [400/1500], Loss: 1.4529, Validation Loss: 1.4262
# Epoch [500/1500], Loss: 1.4384, Validation Loss: 1.3938
# Epoch [600/1500], Loss: 1.4301, Validation Loss: 1.3835
# Epoch [700/1500], Loss: 1.4254, Validation Loss: 1.3782
# Epoch [800/1500], Loss: 1.4227, Validation Loss: 1.3757
# Epoch [900/1500], Loss: 1.4208, Validation Loss: 1.3739
# Epoch [1000/1500], Loss: 1.4196, Validation Loss: 1.3723
# Epoch [1100/1500], Loss: 1.4185, Validation Loss: 1.3711
# Epoch [1200/1500], Loss: 1.4177, Validation Loss: 1.3702
# Epoch [1300/1500], Loss: 1.4169, Validation Loss: 1.3692
# Epoch [1400/1500], Loss: 1.4162, Validation Loss: 1.3683
# Epoch [1500/1500], Loss: 1.4156, Validation Loss: 1.3674
# Training complete!
# Trial 6 completed. Results saved.
# Trial 7
# Epoch [100/1500], Loss: 1.5844, Validation Loss: 1.6108
# Epoch [200/1500], Loss: 1.4847, Validation Loss: 1.5051
# Epoch [300/1500], Loss: 1.4489, Validation Loss: 1.4652
# Epoch [400/1500], Loss: 1.4344, Validation Loss: 1.4485
# Epoch [500/1500], Loss: 1.4275, Validation Loss: 1.4404
# Epoch [600/1500], Loss: 1.4236, Validation Loss: 1.4361
# Epoch [700/1500], Loss: 1.4212, Validation Loss: 1.4330
# Epoch [800/1500], Loss: 1.4195, Validation Loss: 1.4308
# Epoch [900/1500], Loss: 1.4181, Validation Loss: 1.4289
# Epoch [1000/1500], Loss: 1.4170, Validation Loss: 1.4273
# Epoch [1100/1500], Loss: 1.4160, Validation Loss: 1.4258
# Epoch [1200/1500], Loss: 1.4151, Validation Loss: 1.4242
# Epoch [1300/1500], Loss: 1.4144, Validation Loss: 1.4227
# Epoch [1400/1500], Loss: 1.4137, Validation Loss: 1.4213
# Epoch [1500/1500], Loss: 1.4130, Validation Loss: 1.4198
# Training complete!
# Trial 7 completed. Results saved.
# Trial 8
# Epoch [100/1500], Loss: 1.5829, Validation Loss: 1.6187
# Epoch [200/1500], Loss: 1.4895, Validation Loss: 1.5348
# Epoch [300/1500], Loss: 1.4569, Validation Loss: 1.5021
# Epoch [400/1500], Loss: 1.4343, Validation Loss: 1.3905
# Epoch [500/1500], Loss: 1.4228, Validation Loss: 1.3681
# Epoch [600/1500], Loss: 1.4167, Validation Loss: 1.3606
# Epoch [700/1500], Loss: 1.4133, Validation Loss: 1.3562
# Epoch [800/1500], Loss: 1.4109, Validation Loss: 1.3539
# Epoch [900/1500], Loss: 1.4090, Validation Loss: 1.3524
# Epoch [1000/1500], Loss: 1.4075, Validation Loss: 1.3513
# Early stopping at epoch 1080
# Training complete!
# Trial 8 completed. Results saved.
# Trial 9
# Epoch [100/1500], Loss: 1.5511, Validation Loss: 1.5944
# Epoch [200/1500], Loss: 1.4663, Validation Loss: 1.5281
# Epoch [300/1500], Loss: 1.4388, Validation Loss: 1.5047
# Epoch [400/1500], Loss: 1.4266, Validation Loss: 1.4940
# Epoch [500/1500], Loss: 1.4206, Validation Loss: 1.4899
# Epoch [600/1500], Loss: 1.4173, Validation Loss: 1.4879
# Epoch [700/1500], Loss: 1.4150, Validation Loss: 1.4863
# Epoch [800/1500], Loss: 1.4133, Validation Loss: 1.4848
# Epoch [900/1500], Loss: 1.4119, Validation Loss: 1.4832
# Epoch [1000/1500], Loss: 1.4107, Validation Loss: 1.4812
# Epoch [1100/1500], Loss: 1.4096, Validation Loss: 1.4783
# Epoch [1200/1500], Loss: 1.4087, Validation Loss: 1.4731
# Epoch [1300/1500], Loss: 1.3994, Validation Loss: 1.3708
# Early stopping at epoch 1304
# Training complete!
# Trial 9 completed. Results saved.
# Trial 10
# Epoch [100/1500], Loss: 1.5889, Validation Loss: 1.6203
# Epoch [200/1500], Loss: 1.5049, Validation Loss: 1.5394
# Epoch [300/1500], Loss: 1.4747, Validation Loss: 1.5070
# Epoch [400/1500], Loss: 1.4615, Validation Loss: 1.4923
# Epoch [500/1500], Loss: 1.4553, Validation Loss: 1.4858
# Epoch [600/1500], Loss: 1.4517, Validation Loss: 1.4818
# Epoch [700/1500], Loss: 1.4492, Validation Loss: 1.4789
# Epoch [800/1500], Loss: 1.4474, Validation Loss: 1.4764
# Epoch [900/1500], Loss: 1.4461, Validation Loss: 1.4746
# Epoch [1000/1500], Loss: 1.4451, Validation Loss: 1.4733
# Epoch [1100/1500], Loss: 1.4443, Validation Loss: 1.4720
# Epoch [1200/1500], Loss: 1.4435, Validation Loss: 1.4705
# Epoch [1300/1500], Loss: 1.4428, Validation Loss: 1.4688
# Epoch [1400/1500], Loss: 1.4421, Validation Loss: 1.4667
# Epoch [1500/1500], Loss: 1.4414, Validation Loss: 1.4627
# Training complete!
# Trial 10 completed. Results saved.
# Trial 11
# Epoch [100/1500], Loss: 1.5974, Validation Loss: 1.6310
# Epoch [200/1500], Loss: 1.4989, Validation Loss: 1.5418
# Epoch [300/1500], Loss: 1.4623, Validation Loss: 1.5057
# Epoch [400/1500], Loss: 1.4470, Validation Loss: 1.4900
# Epoch [500/1500], Loss: 1.4391, Validation Loss: 1.4820
# Epoch [600/1500], Loss: 1.4346, Validation Loss: 1.4774
# Epoch [700/1500], Loss: 1.4317, Validation Loss: 1.4744
# Epoch [800/1500], Loss: 1.4296, Validation Loss: 1.4719
# Epoch [900/1500], Loss: 1.4279, Validation Loss: 1.4698
# Epoch [1000/1500], Loss: 1.4264, Validation Loss: 1.4677
# Epoch [1100/1500], Loss: 1.4252, Validation Loss: 1.4655
# Epoch [1200/1500], Loss: 1.4241, Validation Loss: 1.4628
# Epoch [1300/1500], Loss: 1.4232, Validation Loss: 1.4587
# Epoch [1400/1500], Loss: 1.4127, Validation Loss: 1.3679
# Epoch [1500/1500], Loss: 1.4097, Validation Loss: 1.3576
# Training complete!
# Trial 11 completed. Results saved.
# Trial 12
# Epoch [100/1500], Loss: 1.5656, Validation Loss: 1.5835
# Epoch [200/1500], Loss: 1.4520, Validation Loss: 1.4830
# Epoch [300/1500], Loss: 1.4164, Validation Loss: 1.4528
# Epoch [400/1500], Loss: 1.4018, Validation Loss: 1.4402
# Epoch [500/1500], Loss: 1.3942, Validation Loss: 1.4333
# Epoch [600/1500], Loss: 1.3896, Validation Loss: 1.4290
# Epoch [700/1500], Loss: 1.3865, Validation Loss: 1.4263
# Epoch [800/1500], Loss: 1.3842, Validation Loss: 1.4243
# Epoch [900/1500], Loss: 1.3823, Validation Loss: 1.4229
# Epoch [1000/1500], Loss: 1.3808, Validation Loss: 1.4217
# Early stopping at epoch 1020
# Training complete!
# Trial 12 completed. Results saved.
# Trial 13
# Epoch [100/1500], Loss: 1.5899, Validation Loss: 1.6339
# Epoch [200/1500], Loss: 1.4841, Validation Loss: 1.5708
# Epoch [300/1500], Loss: 1.4491, Validation Loss: 1.5516
# Epoch [400/1500], Loss: 1.4354, Validation Loss: 1.5455
# Epoch [500/1500], Loss: 1.4286, Validation Loss: 1.5421
# Epoch [600/1500], Loss: 1.4245, Validation Loss: 1.5395
# Epoch [700/1500], Loss: 1.4218, Validation Loss: 1.5373
# Epoch [800/1500], Loss: 1.4198, Validation Loss: 1.5345
# Epoch [900/1500], Loss: 1.4178, Validation Loss: 1.5262
# Early stopping at epoch 962
# Training complete!
# Trial 13 completed. Results saved.
# Trial 14
# Epoch [100/1500], Loss: 1.5832, Validation Loss: 1.6056
# Epoch [200/1500], Loss: 1.4873, Validation Loss: 1.4854
# Epoch [300/1500], Loss: 1.4426, Validation Loss: 1.3842
# Epoch [400/1500], Loss: 1.4276, Validation Loss: 1.3681
# Epoch [500/1500], Loss: 1.4198, Validation Loss: 1.3607
# Epoch [600/1500], Loss: 1.4150, Validation Loss: 1.3561
# Epoch [700/1500], Loss: 1.4119, Validation Loss: 1.3537
# Epoch [800/1500], Loss: 1.4099, Validation Loss: 1.3520
# Epoch [900/1500], Loss: 1.4085, Validation Loss: 1.3508
# Early stopping at epoch 941
# Training complete!
# Trial 14 completed. Results saved.
# Trial 15
# Epoch [100/1500], Loss: 1.5828, Validation Loss: 1.5962
# Epoch [200/1500], Loss: 1.4969, Validation Loss: 1.5112
# Epoch [300/1500], Loss: 1.4668, Validation Loss: 1.4772
# Epoch [400/1500], Loss: 1.4539, Validation Loss: 1.4619
# Epoch [500/1500], Loss: 1.4473, Validation Loss: 1.4543
# Epoch [600/1500], Loss: 1.4434, Validation Loss: 1.4498
# Epoch [700/1500], Loss: 1.4411, Validation Loss: 1.4471
# Epoch [800/1500], Loss: 1.4395, Validation Loss: 1.4448
# Epoch [900/1500], Loss: 1.4383, Validation Loss: 1.4428
# Epoch [1000/1500], Loss: 1.4373, Validation Loss: 1.4409
# Epoch [1100/1500], Loss: 1.4366, Validation Loss: 1.4389
# Epoch [1200/1500], Loss: 1.4359, Validation Loss: 1.4371
# Epoch [1300/1500], Loss: 1.4353, Validation Loss: 1.4352
# Epoch [1400/1500], Loss: 1.4346, Validation Loss: 1.4328
# Epoch [1500/1500], Loss: 1.4340, Validation Loss: 1.4295
# Training complete!
# Trial 15 completed. Results saved.
# Trial 16
# Epoch [100/1500], Loss: 1.5789, Validation Loss: 1.5959
# Epoch [200/1500], Loss: 1.4902, Validation Loss: 1.5159
# Epoch [300/1500], Loss: 1.4603, Validation Loss: 1.4878
# Epoch [400/1500], Loss: 1.4484, Validation Loss: 1.4765
# Epoch [500/1500], Loss: 1.4424, Validation Loss: 1.4705
# Epoch [600/1500], Loss: 1.4392, Validation Loss: 1.4676
# Epoch [700/1500], Loss: 1.4374, Validation Loss: 1.4660
# Epoch [800/1500], Loss: 1.4362, Validation Loss: 1.4647
# Epoch [900/1500], Loss: 1.4352, Validation Loss: 1.4635
# Epoch [1000/1500], Loss: 1.4344, Validation Loss: 1.4622
# Epoch [1100/1500], Loss: 1.4337, Validation Loss: 1.4606
# Epoch [1200/1500], Loss: 1.4329, Validation Loss: 1.4583
# Epoch [1300/1500], Loss: 1.4322, Validation Loss: 1.4550
# Epoch [1400/1500], Loss: 1.4300, Validation Loss: 1.4305
# Epoch [1500/1500], Loss: 1.4195, Validation Loss: 1.3426
# Training complete!
# Trial 16 completed. Results saved.
# Trial 17
# Epoch [100/1500], Loss: 1.5858, Validation Loss: 1.6032
# Epoch [200/1500], Loss: 1.4921, Validation Loss: 1.5053
# Epoch [300/1500], Loss: 1.4588, Validation Loss: 1.4668
# Epoch [400/1500], Loss: 1.4450, Validation Loss: 1.4504
# Epoch [500/1500], Loss: 1.4381, Validation Loss: 1.4422
# Epoch [600/1500], Loss: 1.4343, Validation Loss: 1.4379
# Epoch [700/1500], Loss: 1.4319, Validation Loss: 1.4350
# Epoch [800/1500], Loss: 1.4301, Validation Loss: 1.4328
# Epoch [900/1500], Loss: 1.4286, Validation Loss: 1.4309
# Epoch [1000/1500], Loss: 1.4274, Validation Loss: 1.4295
# Epoch [1100/1500], Loss: 1.4263, Validation Loss: 1.4281
# Epoch [1200/1500], Loss: 1.4253, Validation Loss: 1.4269
# Epoch [1300/1500], Loss: 1.4245, Validation Loss: 1.4257
# Epoch [1400/1500], Loss: 1.4238, Validation Loss: 1.4244
# Epoch [1500/1500], Loss: 1.4230, Validation Loss: 1.4227
# Training complete!
# Trial 17 completed. Results saved.
# Trial 18
# Epoch [100/1500], Loss: 1.6189, Validation Loss: 1.6187
# Epoch [200/1500], Loss: 1.5168, Validation Loss: 1.4670
# Epoch [300/1500], Loss: 1.4761, Validation Loss: 1.4126
# Epoch [400/1500], Loss: 1.4618, Validation Loss: 1.3929
# Epoch [500/1500], Loss: 1.4548, Validation Loss: 1.3831
# Epoch [600/1500], Loss: 1.4508, Validation Loss: 1.3775
# Epoch [700/1500], Loss: 1.4480, Validation Loss: 1.3741
# Epoch [800/1500], Loss: 1.4459, Validation Loss: 1.3718
# Epoch [900/1500], Loss: 1.4442, Validation Loss: 1.3700
# Epoch [1000/1500], Loss: 1.4427, Validation Loss: 1.3682
# Epoch [1100/1500], Loss: 1.4414, Validation Loss: 1.3667
# Epoch [1200/1500], Loss: 1.4404, Validation Loss: 1.3655
# Epoch [1300/1500], Loss: 1.4396, Validation Loss: 1.3645
# Epoch [1400/1500], Loss: 1.4389, Validation Loss: 1.3637
# Epoch [1500/1500], Loss: 1.4383, Validation Loss: 1.3630
# Training complete!
# Trial 18 completed. Results saved.
# Trial 19
# Epoch [100/1500], Loss: 1.5912, Validation Loss: 1.5898
# Epoch [200/1500], Loss: 1.5001, Validation Loss: 1.4925
# Epoch [300/1500], Loss: 1.4669, Validation Loss: 1.4518
# Epoch [400/1500], Loss: 1.4530, Validation Loss: 1.4336
# Epoch [500/1500], Loss: 1.4464, Validation Loss: 1.4246
# Epoch [600/1500], Loss: 1.4426, Validation Loss: 1.4190
# Epoch [700/1500], Loss: 1.4403, Validation Loss: 1.4153
# Epoch [800/1500], Loss: 1.4387, Validation Loss: 1.4126
# Epoch [900/1500], Loss: 1.4374, Validation Loss: 1.4104
# Epoch [1000/1500], Loss: 1.4364, Validation Loss: 1.4084
# Epoch [1100/1500], Loss: 1.4355, Validation Loss: 1.4066
# Epoch [1200/1500], Loss: 1.4348, Validation Loss: 1.4049
# Epoch [1300/1500], Loss: 1.4341, Validation Loss: 1.4030
# Epoch [1400/1500], Loss: 1.4335, Validation Loss: 1.4006
# Epoch [1500/1500], Loss: 1.4327, Validation Loss: 1.3972
# Training complete!
# Trial 19 completed. Results saved.
# Trial 20
# Epoch [100/1500], Loss: 1.5790, Validation Loss: 1.5906
# Epoch [200/1500], Loss: 1.4744, Validation Loss: 1.4553
# Epoch [300/1500], Loss: 1.4366, Validation Loss: 1.4087
# Epoch [400/1500], Loss: 1.4209, Validation Loss: 1.3890
# Epoch [500/1500], Loss: 1.4128, Validation Loss: 1.3789
# Epoch [600/1500], Loss: 1.4079, Validation Loss: 1.3733
# Epoch [700/1500], Loss: 1.4049, Validation Loss: 1.3695
# Epoch [800/1500], Loss: 1.4030, Validation Loss: 1.3673
# Epoch [900/1500], Loss: 1.4018, Validation Loss: 1.3664
# Epoch [1000/1500], Loss: 1.4009, Validation Loss: 1.3657
# Epoch [1100/1500], Loss: 1.4003, Validation Loss: 1.3653
# Epoch [1200/1500], Loss: 1.3997, Validation Loss: 1.3650
# Early stopping at epoch 1205
# Training complete!
# Trial 20 completed. Results saved.
