# %% [markdown]
# ## 時間情報のない集団データ

# %% [markdown]
# ### 方針

# %% [markdown]
# ・内部に問題ごとの依存関係を定義し、その関係をもとに遷移させる。
#
# ・条件付き確率（遷移確率）と周辺分布の積の和から次の周辺分布を求める。
#
# ・まずは遷移過程が部分的にしか分からない人工データを用意し、モデルを学習する。

# %% [markdown]
# ## 人工データ生成

# %%
import numpy as np

# 問題の依存関係の行列 A 
A = np.array([
    [0, 0, 0, 0, 0, 0],  # 初期状態
    [1, 0, 0, 0, 0, 0],  # 問題1は初期状態のみに依存
    [1, 0, 0, 0, 0, 0],  # 問題2は問題1に依存
    [0, 1, 1, 0, 0, 0],  # 問題3は問題2に依存
    [0, 0, 0, 1, 0, 0],  # 問題4は問題2、問題3に依存
    [0, 0, 0, 0, 1, 0]   # 問題4は問題2、問題3に依存
], dtype = float)*3

# 0でない要素の数で割る処理
nonzero_counts = np.count_nonzero(A[1:], axis=1, keepdims=True)
A[1:] = np.where(nonzero_counts != 0, A[1:] / nonzero_counts, 0)

# 遷移確率を計算する関数
def calculate_transition_probabilities(A, X):
    n = len(X)
    raw_probabilities = np.zeros(n)  # 遷移確率の元となる値
    
    # 不正解の問題に対して遷移確率を計算
    for i in range(n):
        if X[i] == 0:  # まだ正解していない問題のみ対象
            required_problems = A[i, :]  # i番目の問題に必要な依存関係
            
            solved_problems = X * required_problems  # 現状解けている
            
            num_solved = np.sum(solved_problems)      # 実際に解けた問題の数
            
            raw_probabilities[i] = np.exp(num_solved)
    
    # 総和で割って正規化
    total_sum = np.sum(raw_probabilities)  # expの総和
    if total_sum > 0:  # 総和が0でなければ正規化
        probabilities = raw_probabilities / total_sum
    else:
        probabilities = raw_probabilities  # 総和が0ならそのまま
    
    return probabilities

# %%
# 教師データセットを生成する関数
def generate_training_data(A, initial_X, num_correct_problems, num_data_per_step):
    n = len(initial_X)  # 問題数
    dataset = []
    
    # 各ステップでデータを生成
    for i in range(num_correct_problems, num_correct_problems+1):  # 1問以上の正解を対象にする
        for j in range(num_data_per_step):  # 各ステップごとにデータ数
            X = initial_X.copy()  # 初期状態からスタート
            
            # i問正解させる
            for k in range(i):
                input_X = X.copy()    # 遷移前状態を保持
                probabilities = calculate_transition_probabilities(A, X)
                
                if np.sum(probabilities) > 0:  # 正規化された確率がある場合
                    # 確率に基づいて次に正解させる問題を選択
                    next_correct_problem = np.random.choice(n, p=probabilities)
                    X[next_correct_problem] = 1  # 選ばれた問題を正解に遷移させる
            
                # 初期状態と1ステップ後の状態の差分を教師データとして使用
                target_Y = (X - input_X).clip(min=0)  # 0から1に変わった部分のみを1、他は0
                
                # 初期状態（入力）と差分（教師データ）のペアを保存
                dataset.append((input_X.copy(), target_Y.copy()))  # (入力データ, 教師データ)
    
    return dataset

# %%
import torch

import itertools
from collections import defaultdict

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
def _bcsoftmax1d(x, budget):
    """Budget Constrained Softmax function for vector.

    Args:
        x (Tensor): input vector. shape: (n_outputs, )
        budget (Tensor): budget (constraint) vector. shape: (n_outputs, )

    Returns:
        y (Tensor): output probability vector. shape: (n_outputs, ). Satisfying the constraints y_i <= budget_i.
    
    """
    x = x - torch.max(x, dim=0)[0] # normalization to avoid numerical errors
    exp_x = torch.exp(x)
    # sorting
    _, indices = torch.sort(budget / exp_x, descending=False)
    exp_x = exp_x[indices]
    budget = budget[indices]
    # find K_B
    r = torch.flip(torch.cumsum(torch.flip(exp_x, dims=(0, )), dim=0), dims=(0, ))
    s = 1.0 - (torch.cumsum(budget, dim=0) - budget)
    z = r / s
    is_in_KB = torch.logical_and(
        (s - budget) > 0, exp_x / z > budget
    )
    # compute outputs
    s = 1 - torch.sum(budget * is_in_KB)
    r = torch.sum(exp_x * (~is_in_KB))
    y = torch.where(~is_in_KB, s * exp_x / r, budget)
    # undo sorting
    _, inv_indices = torch.sort(indices, descending=False)
    return y[inv_indices]


def _bcsoftmax1d_stable(x, budget):
    """Budget Constrained Softmax function for vector.
    This function is more numerically stable than `_bcsoftmax1d` by computing some values in log-scale.
    
    Args:
        x (Tensor): input vector. shape: (n_outputs, )
        budget (Tensor): budget (constraint) vector. shape: (n_outputs, )

    Returns:
        y (Tensor): output probability vector. shape: (n_outputs, ). Satisfying the constraints y_i <= budget_i.
    
    """
    # sorting
    _, indices = torch.sort(torch.log(budget) - x, descending=False)
    x = x[indices]
    budget = budget[indices]
    # find K_B
    log_r = torch.flip(torch.logcumsumexp(torch.flip(x, dims=(0, )), dim=0), dims=(0, ))
    s = 1.0 - (torch.cumsum(budget, dim=0) - budget)
    is_in_KB = torch.logical_or(
        budget == 0,
        torch.logical_and(
            s - budget > 0,
            x - log_r + torch.log(s) > torch.log(budget)
        )
    )
    # compute outputs
    exp_x = torch.exp(x - torch.max(torch.where(~is_in_KB, x, -torch.inf), dim=0)[0])
    s = 1 - torch.sum(budget * is_in_KB)
    r = torch.sum(exp_x * (~is_in_KB))
    y = torch.where(~is_in_KB, s * exp_x / r, budget)
    # undo sorting
    _, inv_indices = torch.sort(indices, descending=False)
    return y[inv_indices]


class BCSoftmax1d(torch.autograd.Function):
    """Autograd implementation of Budget Constrained Softmax function for vector.
    """
    generate_vmap_rule = True
    
    @staticmethod
    def forward(x, c):
        y = _bcsoftmax1d_stable(x, c)
        return y

    @staticmethod
    def setup_context(ctx, inputs, output):
        x, c = inputs
        is_in_KB = c == output
        ctx.save_for_backward(x, c, is_in_KB)
    
    @staticmethod
    def backward(ctx, grad_y):
        x, c, is_in_KB = ctx.saved_tensors
        exp_x = torch.exp(
            x - torch.max(torch.where(~is_in_KB, x, -torch.inf), dim=0)[0]
        )
        s = 1 - torch.sum(c * is_in_KB)
        r = torch.sum(exp_x * (~is_in_KB))
        
        # compute Jacobian
        Jx = torch.where(
            torch.outer(~is_in_KB, ~is_in_KB),
            torch.diag(~is_in_KB * exp_x) * r - torch.outer(exp_x, exp_x),
            0,
        )
        Jx *= torch.where(
            s > 0,
            s / (r * r),
            0
        )
        Jc = torch.where(
            torch.outer(~is_in_KB, is_in_KB),
            - exp_x[:, None] / r,
            1.0 * torch.diag(is_in_KB)
        )

        # print("s", s, "r", r)
        # print("勾配", torch.matmul(grad_y, Jx), torch.matmul(grad_y, Jc))
        assert not torch.isnan(torch.matmul(grad_y, Jx)).any(), "Jx contains NaN"
        assert not torch.isinf(torch.matmul(grad_y, Jx)).any(), "Jx contains Inf"
        assert not torch.isnan(torch.matmul(grad_y, Jc)).any(), "Jc contains NaN"
        assert not torch.isinf(torch.matmul(grad_y, Jc)).any(), "Jc contains Inf"

        # return vector-Jacobian product
        return torch.matmul(grad_y, Jx), torch.matmul(grad_y, Jc)

# %%
######### Use these functions! #########
bcsoftmax1d = BCSoftmax1d.apply

# データによってmodelを通す回数が違
# bcsoftmax2d = torch.vmap(BCSoftmax1d.apply) # input shape = (batch_size, n_classes)

# %%
class Model(nn.Module):
    def __init__(self, num_questions):
        super(Model, self).__init__()
        self.fc = nn.Linear(num_questions, num_questions, bias=False)  # 全結合層

    def forward(self, x, c):
        x = self.fc(x)  # 全結合層の適用
        x = bcsoftmax1d(x, c)
        return x

# %%
"評価指標"

def kl_divergence(p, q, epsilon=1e-10):
    """
    KLダイバージェンスを計算する関数（qが0の場合の無限大問題を回避）
    
    Parameters:
        p (numpy.ndarray): 真の確率分布
        q (numpy.ndarray): 予測確率分布
        epsilon (float): スムージングパラメータ（非常に小さい値）
    
    Returns:
        float: KLダイバージェンス
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)
    
    # pとqにスムージングを適用
    p = np.where(p == 0, epsilon, p)
    q = np.where(q == 0, epsilon, q)
    
    # KLダイバージェンスの計算
    return np.sum(p * np.log(p / q))

def hellinger_distance(p, q):
    """
    Hellinger距離を計算する関数

    Parameters:
        p (numpy.ndarray): 真の分布 [batch_size, num_classes]
        q (numpy.ndarray): 予測分布 [batch_size, num_classes]
    
    Returns:
        float: Hellinger距離の平均値
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)
    # Hellinger距離の計算式: H(p, q) = (1/√2) * ||√p - √q||_2
    sqrt_p = np.sqrt(p)
    sqrt_q = np.sqrt(q)
    distance = np.sqrt(np.sum((sqrt_p - sqrt_q) ** 2)) / np.sqrt(2)
    return np.mean(distance)

def jensen_shannon_divergence(p, q):
    """
    Jensen-Shannon divergence を計算する関数

    Parameters:
        p (numpy.ndarray): 真の分布 [batch_size, num_classes]
        q (numpy.ndarray): 予測分布 [batch_size, num_classes]
    
    Returns:
        float: Jensen-Shannon divergence の平均値
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)

    # 0 の値があると log(0) が発生するため、微小値を加える
    epsilon = 1e-12
    p = np.clip(p, epsilon, 1)
    q = np.clip(q, epsilon, 1)
    
    # 分布の平均 M
    m = 0.5 * (p + q)
    
    # Kullback-Leibler divergence の補助関数
    def kl(a, b):
        return np.sum(a * np.log(a / b))
    
    # JSD の計算: JSD(p || q) = 0.5 * (KL(p || M) + KL(q || M))
    jsd = 0.5 * (kl(p, m) + kl(q, m))
    
    # 各サンプルの平均を返す
    return np.mean(jsd)


def evaluate_model(r, p, q):
    """
    遷移確率の真値と予測値の類似性を評価する関数
    :param r: 各ノードの重み (np.array)
    :param p: 各ノードの真の遷移確率 (2D np.array: ノード数 x 遷移確率)
    :param q: 各ノードの予測遷移確率 (2D np.array: ノード数 x 遷移確率)
    :return: 評価指標 L
    """
    L = 0
    for k in range(len(r)):
        L += r[k] * kl_divergence(p[k], q[k])
    return L

# %%
# データセットの生成
num_questions = 5  # 問題数
num_data_per_step = 50     # 各ステップごとに生成するデータ数

num_epochs = 1500  # エポック数
alpha = 0.001 # 正則化パラメータ
early_stopping_patience = 10  # Early Stopping の patience

split_ratio = 0.8  # 学習データと検証データの分割比率

# %%
"実験結果を保存する外部ファイル"
import csv
from datetime import datetime

# 今日の日付を "YYYY-MM-DD" 形式で取得
today = datetime.now().strftime("%Y-%m-%d")

# ファイル名に日付を含める
results_csv = f"results_path_{today}_{num_questions}_{num_data_per_step}_{num_data_per_step}_{split_ratio}.csv"

# 初回にヘッダーを追加する
header = [
    "Iteration", 
    "KL_Model_allpath_same_n",
    "HD_Model_allpath_same_n",
    "JSD_Model_allpath_same_n",
]

try:
    with open(results_csv, "x", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(header)
except FileExistsError:
    pass  # ファイルが既に存在する場合は何もしない

# %%
for trial in range(20):
    print(f"Trial {trial + 1}")

    "データ生成"

    # 生徒の回答状況 X (1が正解、0が不正解)
    # 初期状態は全て不正解
    X_init = np.array([1, 0, 0, 0, 0, 0])

    training_data = generate_training_data(A, X_init, num_questions, num_data_per_step)
    train_X = [input_data for input_data, _ in training_data]
    train_Y = [target_data for _, target_data in training_data]

    
    # データをトレーニングと検証に分割（正解数のバランスが良くなるように分割）
    # 8:2に分割
    def split_balanced_data(train_X, train_Y, ratio=0.8):
        data_per_correct_count = defaultdict(list)
        for x, y in zip(train_X, train_Y):
            correct_count = sum(y)
            data_per_correct_count[correct_count].append((x, y))

        train_X_data, train_Y_data, val_X_data, val_Y_data = [], [], [], []
        for correct_count, data in data_per_correct_count.items():
            split_index = int(len(data) * ratio)
            train_data = data[:split_index]
            val_data = data[split_index:]
            train_X_data.extend([x for x, y in train_data])
            train_Y_data.extend([y for x, y in train_data])
            val_X_data.extend([x for x, y in val_data])
            val_Y_data.extend([y for x, y in val_data])

        return train_X_data, train_Y_data, val_X_data, val_Y_data

    train_X_data, train_Y_data, val_X_data, val_Y_data = split_balanced_data(train_X, train_Y, split_ratio)

    # PyTorch テンソルに変換
    train_X = torch.tensor(train_X_data, dtype=torch.float32)
    train_Y = torch.tensor(train_Y_data, dtype=torch.float32)
    val_X = torch.tensor(val_X_data, dtype=torch.float32)
    val_Y = torch.tensor(val_Y_data, dtype=torch.float32)

    "状態定義"

    # Generate states where the first digit is always 1
    states = [(1,) + state for state in itertools.product([0, 1], repeat=num_questions)]

    states = sorted(states, key=lambda state: sum(state))

    # Initialize the state counts
    state_counts = defaultdict(int)

    # Assuming 'dataset' is your list of student results
    for result, result2 in training_data:
        # print(result2)
        state_tuple = tuple(map(int, result + result2))  # Convert np.int64 to int
        state_counts[state_tuple] += 1  # Count only if the first digit is 1

    # Display the counts for each state
    for state in states:
        count = state_counts[state]
        formatted_state = list(state)  # Convert tuple to list for the desired format

    "モデル定義"
    # モデル、損失関数、最適化関数の設定
    model = Model(num_questions+1)  # 5問+初期状態の問題を扱うモデル
    criterion = nn.CrossEntropyLoss()  # クロスエントロピー損失
    optimizer = optim.Adam(model.parameters(), lr=0.01)

    "学習"
    best_val_loss = float('inf')
    early_stopping_counter = 0

    for epoch in range(num_epochs):
        model.train()  # モデルを訓練モードに
        optimizer.zero_grad()  # 勾配の初期化
        
        outputs = []  # 出力を保持するリスト
        # 各データに対して train_Y の値に基づいてループを実行
        for i, target in enumerate(train_Y):
            c = torch.ones(num_questions+1, dtype=torch.float32)
            output = train_X[i]  # 各 i 番目の入力データを使用
            output = output.view(-1)

            # もしcの和が1なら、rが0となるので対応
            if c.sum() <= 1:
                # print("aaaaaaaa")
                output = c
            else:
                output = model(output, c)  # 前回の出力を次のステップの入力として使用

            outputs.append(output)  # 最終的な出力を保存

        # outputs を適切な形に変換して損失計算（例えば torch.stack を使用）
        outputs = torch.stack(outputs)
        outputs = outputs.squeeze(1)

        # モデルの出力の確認
        assert not torch.isnan(outputs).any(), "Model output contains NaN"
        assert not torch.isinf(outputs).any(), "Model output contains Inf"

        # L1正則化項の計算
        l1_reg = torch.tensor(0.0, requires_grad=True)
        for param in model.parameters():
            l1_reg = l1_reg + torch.sum(torch.abs(param))

        # 損失の計算
        loss0 = criterion(outputs, train_Y)

        loss = loss0 + alpha * l1_reg  # L1正則化項を追加した損失

        # 損失の確認
        assert not torch.isnan(loss).any(), "Loss contains NaN"
        assert not torch.isinf(loss).any(), "Loss contains Inf"

        # バックプロパゲーションとパラメータの更新
        loss.backward()
        optimizer.step()

        # 検証フェーズ
        model.eval()  # モデルを評価モードに
        with torch.no_grad():
            val_outputs = []
            for i, target in enumerate(val_Y):
                c = torch.cat([torch.tensor([0.0]), torch.ones(num_questions, dtype=torch.float32)])
                output = val_X[i]  # 各 i 番目の入力データを使用
                output = output.view(-1)
                for _ in range(int(sum(target))):
                    if c.sum() <= 1:
                        output_0 = c
                    else:
                        output_0 = model(output, c)
                    output = output_0 + output
                    c = c - output_0
                val_outputs.append(output - val_X[i])

            val_outputs = torch.stack(val_outputs)
            val_outputs = val_outputs.squeeze(1)
            val_loss0 = criterion(val_outputs, val_Y)
            val_loss = val_loss0 + alpha * l1_reg

        # Early Stopping の処理
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stopping_counter = 0
        else:
            early_stopping_counter += 1

        if early_stopping_counter >= early_stopping_patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

        # 100エポックごとに損失を表示
        if (epoch+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {val_loss.item():.4f}')

    # 学習結果の確認
    print("Training complete!")

    "モデル評価"
    node_probabilities = defaultdict(float)
    start = (1,) + tuple(0 for _ in range(num_questions))
    node_probabilities[start] = 1

    # 機械学習モデルと簡易モデル
    KL = 0
    HD = 0
    JSD = 0

    for state in states:
        probabilities = calculate_transition_probabilities(A, np.array(state))

        # 最下層から頂点までのノードの分布を順に計算
        for i in range(num_questions + 1):
            if state[i] == 0:  # まだ解けていない問題
                # 遷移後の状態
                next_state = list(state)
                next_state[i] = 1
                next_state = tuple(next_state)
                node_probabilities[next_state] += probabilities[i] * node_probabilities[state]
        
        # budgetの計算
        c_g = torch.ones(num_questions+1, dtype=torch.float32)
        c_g = c_g - torch.tensor(state, dtype=torch.float32)

        # 状態とその予測分布
        state_tensor = torch.tensor(state, dtype=torch.float32)
        predicted_values = model(state_tensor, c_g)  # 予測値を計算

    # 評価指標の計算
        kl = node_probabilities[state] * kl_divergence(probabilities, predicted_values.detach())
        hd = node_probabilities[state] * hellinger_distance(probabilities, predicted_values.detach())
        jsd = node_probabilities[state] * jensen_shannon_divergence(probabilities, predicted_values.detach())
        # print(f"状態: {state}, ノード分布: {node_probabilities[state]:.3g}, KL: {kl:.3g}, HD: {hd:.3g}, JSD: {jsd:.3g}")
        # print(f"真の遷移確率: {probabilities}, 予測遷移確率: {predicted_values}")
        KL += kl
        HD += hd
        JSD += jsd


    # 試行ごとの指標をCSVに追記
    with open(results_csv, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([
            trial + 1,
            KL,
            HD,
            JSD
        ])

    print(f"Trial {trial + 1} completed. Results saved.")
# Out:
# Trial 1
# /var/folders/zg/773ptkr55z99zw26dvy19_v00000gn/T/ipykernel_21861/2721460592.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   train_X = torch.tensor(train_X_data, dtype=torch.float32)
# Epoch [100/1500], Loss: 1.5646, Validation Loss: 1.5368
# Epoch [200/1500], Loss: 1.4241, Validation Loss: 1.4087
# Epoch [300/1500], Loss: 1.3707, Validation Loss: 1.3531
# Epoch [400/1500], Loss: 1.3485, Validation Loss: 1.3285
# Epoch [500/1500], Loss: 1.3372, Validation Loss: 1.3167
# Epoch [600/1500], Loss: 1.3306, Validation Loss: 1.3107
# Epoch [700/1500], Loss: 1.3262, Validation Loss: 1.3066
# Epoch [800/1500], Loss: 1.3231, Validation Loss: 1.3034
# Epoch [900/1500], Loss: 1.3208, Validation Loss: 1.3010
# Epoch [1000/1500], Loss: 1.3191, Validation Loss: 1.2992
# Epoch [1100/1500], Loss: 1.3178, Validation Loss: 1.2980
# Epoch [1200/1500], Loss: 1.3168, Validation Loss: 1.2971
# Epoch [1300/1500], Loss: 1.3160, Validation Loss: 1.2963
# Epoch [1400/1500], Loss: 1.3154, Validation Loss: 1.2957
# Epoch [1500/1500], Loss: 1.3149, Validation Loss: 1.2951
# Training complete!
# Trial 1 completed. Results saved.
# Trial 2
# Epoch [100/1500], Loss: 1.5593, Validation Loss: 1.5961
# Epoch [200/1500], Loss: 1.4204, Validation Loss: 1.4931
# Epoch [300/1500], Loss: 1.3670, Validation Loss: 1.4606
# Epoch [400/1500], Loss: 1.3448, Validation Loss: 1.4522
# Epoch [500/1500], Loss: 1.3333, Validation Loss: 1.4479
# Epoch [600/1500], Loss: 1.3268, Validation Loss: 1.4450
# Epoch [700/1500], Loss: 1.3224, Validation Loss: 1.4425
# Epoch [800/1500], Loss: 1.3191, Validation Loss: 1.4398
# Epoch [900/1500], Loss: 1.3162, Validation Loss: 1.4368
# Epoch [1000/1500], Loss: 1.3137, Validation Loss: 1.4334
# Epoch [1100/1500], Loss: 1.3117, Validation Loss: 1.4304
# Epoch [1200/1500], Loss: 1.3099, Validation Loss: 1.4274
# Epoch [1300/1500], Loss: 1.3085, Validation Loss: 1.4234
# Epoch [1400/1500], Loss: 1.3075, Validation Loss: 1.4198
# Epoch [1500/1500], Loss: 1.3067, Validation Loss: 1.4173
# Training complete!
# Trial 2 completed. Results saved.
# Trial 3
# Epoch [100/1500], Loss: 1.5658, Validation Loss: 1.5454
# Epoch [200/1500], Loss: 1.4269, Validation Loss: 1.4174
# Epoch [300/1500], Loss: 1.3732, Validation Loss: 1.3716
# Epoch [400/1500], Loss: 1.3511, Validation Loss: 1.3514
# Epoch [500/1500], Loss: 1.3401, Validation Loss: 1.3413
# Epoch [600/1500], Loss: 1.3336, Validation Loss: 1.3350
# Epoch [700/1500], Loss: 1.3293, Validation Loss: 1.3305
# Epoch [800/1500], Loss: 1.3263, Validation Loss: 1.3275
# Epoch [900/1500], Loss: 1.3243, Validation Loss: 1.3252
# Epoch [1000/1500], Loss: 1.3228, Validation Loss: 1.3234
# Epoch [1100/1500], Loss: 1.3217, Validation Loss: 1.3221
# Epoch [1200/1500], Loss: 1.3208, Validation Loss: 1.3208
# Epoch [1300/1500], Loss: 1.3202, Validation Loss: 1.3196
# Epoch [1400/1500], Loss: 1.3197, Validation Loss: 1.3188
# Early stopping at epoch 1479
# Training complete!
# Trial 3 completed. Results saved.
# Trial 4
# Epoch [100/1500], Loss: 1.5781, Validation Loss: 1.5532
# Epoch [200/1500], Loss: 1.4276, Validation Loss: 1.3857
# Epoch [300/1500], Loss: 1.3673, Validation Loss: 1.3185
# Epoch [400/1500], Loss: 1.3428, Validation Loss: 1.2886
# Epoch [500/1500], Loss: 1.3306, Validation Loss: 1.2728
# Epoch [600/1500], Loss: 1.3233, Validation Loss: 1.2628
# Epoch [700/1500], Loss: 1.3183, Validation Loss: 1.2557
# Epoch [800/1500], Loss: 1.3147, Validation Loss: 1.2500
# Epoch [900/1500], Loss: 1.3123, Validation Loss: 1.2467
# Epoch [1000/1500], Loss: 1.3106, Validation Loss: 1.2443
# Epoch [1100/1500], Loss: 1.3092, Validation Loss: 1.2425
# Epoch [1200/1500], Loss: 1.3081, Validation Loss: 1.2410
# Epoch [1300/1500], Loss: 1.3071, Validation Loss: 1.2397
# Epoch [1400/1500], Loss: 1.3061, Validation Loss: 1.2387
# Epoch [1500/1500], Loss: 1.3053, Validation Loss: 1.2378
# Training complete!
# Trial 4 completed. Results saved.
# Trial 5
# Epoch [100/1500], Loss: 1.5499, Validation Loss: 1.5224
# Epoch [200/1500], Loss: 1.4103, Validation Loss: 1.3774
# Epoch [300/1500], Loss: 1.3554, Validation Loss: 1.3272
# Epoch [400/1500], Loss: 1.3328, Validation Loss: 1.3068
# Epoch [500/1500], Loss: 1.3215, Validation Loss: 1.2974
# Epoch [600/1500], Loss: 1.3150, Validation Loss: 1.2921
# Epoch [700/1500], Loss: 1.3108, Validation Loss: 1.2883
# Epoch [800/1500], Loss: 1.3078, Validation Loss: 1.2856
# Epoch [900/1500], Loss: 1.3057, Validation Loss: 1.2838
# Epoch [1000/1500], Loss: 1.3040, Validation Loss: 1.2825
# Epoch [1100/1500], Loss: 1.3025, Validation Loss: 1.2814
# Epoch [1200/1500], Loss: 1.3015, Validation Loss: 1.2805
# Epoch [1300/1500], Loss: 1.3006, Validation Loss: 1.2798
# Epoch [1400/1500], Loss: 1.2998, Validation Loss: 1.2791
# Epoch [1500/1500], Loss: 1.2991, Validation Loss: 1.2783
# Training complete!
# Trial 5 completed. Results saved.
# Trial 6
# Epoch [100/1500], Loss: 1.5476, Validation Loss: 1.5631
# Epoch [200/1500], Loss: 1.4058, Validation Loss: 1.4517
# Epoch [300/1500], Loss: 1.3518, Validation Loss: 1.4156
# Epoch [400/1500], Loss: 1.3271, Validation Loss: 1.4019
# Epoch [500/1500], Loss: 1.3134, Validation Loss: 1.3954
# Epoch [600/1500], Loss: 1.3048, Validation Loss: 1.3906
# Epoch [700/1500], Loss: 1.2992, Validation Loss: 1.3874
# Epoch [800/1500], Loss: 1.2955, Validation Loss: 1.3848
# Epoch [900/1500], Loss: 1.2929, Validation Loss: 1.3828
# Epoch [1000/1500], Loss: 1.2908, Validation Loss: 1.3809
# Epoch [1100/1500], Loss: 1.2893, Validation Loss: 1.3793
# Epoch [1200/1500], Loss: 1.2879, Validation Loss: 1.3778
# Early stopping at epoch 1254
# Training complete!
# Trial 6 completed. Results saved.
# Trial 7
# Epoch [100/1500], Loss: 1.5680, Validation Loss: 1.5624
# Epoch [200/1500], Loss: 1.4294, Validation Loss: 1.4265
# Epoch [300/1500], Loss: 1.3751, Validation Loss: 1.3723
# Epoch [400/1500], Loss: 1.3507, Validation Loss: 1.3515
# Epoch [500/1500], Loss: 1.3370, Validation Loss: 1.3418
# Epoch [600/1500], Loss: 1.3281, Validation Loss: 1.3365
# Epoch [700/1500], Loss: 1.3224, Validation Loss: 1.3321
# Epoch [800/1500], Loss: 1.3183, Validation Loss: 1.3285
# Epoch [900/1500], Loss: 1.3153, Validation Loss: 1.3250
# Epoch [1000/1500], Loss: 1.3130, Validation Loss: 1.3219
# Epoch [1100/1500], Loss: 1.3113, Validation Loss: 1.3194
# Epoch [1200/1500], Loss: 1.3100, Validation Loss: 1.3179
# Epoch [1300/1500], Loss: 1.3089, Validation Loss: 1.3169
# Epoch [1400/1500], Loss: 1.3080, Validation Loss: 1.3163
# Early stopping at epoch 1415
# Training complete!
# Trial 7 completed. Results saved.
# Trial 8
# Epoch [100/1500], Loss: 1.5965, Validation Loss: 1.5756
# Epoch [200/1500], Loss: 1.4369, Validation Loss: 1.3976
# Epoch [300/1500], Loss: 1.3744, Validation Loss: 1.3276
# Epoch [400/1500], Loss: 1.3469, Validation Loss: 1.2996
# Epoch [500/1500], Loss: 1.3321, Validation Loss: 1.2862
# Epoch [600/1500], Loss: 1.3229, Validation Loss: 1.2784
# Epoch [700/1500], Loss: 1.3172, Validation Loss: 1.2737
# Epoch [800/1500], Loss: 1.3133, Validation Loss: 1.2704
# Epoch [900/1500], Loss: 1.3104, Validation Loss: 1.2683
# Epoch [1000/1500], Loss: 1.3081, Validation Loss: 1.2663
# Epoch [1100/1500], Loss: 1.3064, Validation Loss: 1.2649
# Epoch [1200/1500], Loss: 1.3049, Validation Loss: 1.2639
# Epoch [1300/1500], Loss: 1.3037, Validation Loss: 1.2631
# Epoch [1400/1500], Loss: 1.3026, Validation Loss: 1.2623
# Epoch [1500/1500], Loss: 1.3017, Validation Loss: 1.2618
# Training complete!
# Trial 8 completed. Results saved.
# Trial 9
# Epoch [100/1500], Loss: 1.5512, Validation Loss: 1.5890
# Epoch [200/1500], Loss: 1.4139, Validation Loss: 1.4948
# Epoch [300/1500], Loss: 1.3616, Validation Loss: 1.4608
# Epoch [400/1500], Loss: 1.3398, Validation Loss: 1.4446
# Epoch [500/1500], Loss: 1.3286, Validation Loss: 1.4355
# Epoch [600/1500], Loss: 1.3220, Validation Loss: 1.4298
# Epoch [700/1500], Loss: 1.3176, Validation Loss: 1.4254
# Epoch [800/1500], Loss: 1.3144, Validation Loss: 1.4221
# Epoch [900/1500], Loss: 1.3118, Validation Loss: 1.4193
# Epoch [1000/1500], Loss: 1.3097, Validation Loss: 1.4170
# Epoch [1100/1500], Loss: 1.3082, Validation Loss: 1.4154
# Early stopping at epoch 1130
# Training complete!
# Trial 9 completed. Results saved.
# Trial 10
# Epoch [100/1500], Loss: 1.5571, Validation Loss: 1.5350
# Epoch [200/1500], Loss: 1.4061, Validation Loss: 1.3830
# Epoch [300/1500], Loss: 1.3529, Validation Loss: 1.3307
# Epoch [400/1500], Loss: 1.3309, Validation Loss: 1.3088
# Epoch [500/1500], Loss: 1.3194, Validation Loss: 1.2976
# Epoch [600/1500], Loss: 1.3122, Validation Loss: 1.2906
# Epoch [700/1500], Loss: 1.3073, Validation Loss: 1.2860
# Epoch [800/1500], Loss: 1.3038, Validation Loss: 1.2830
# Epoch [900/1500], Loss: 1.3012, Validation Loss: 1.2809
# Epoch [1000/1500], Loss: 1.2992, Validation Loss: 1.2792
# Epoch [1100/1500], Loss: 1.2980, Validation Loss: 1.2781
# Epoch [1200/1500], Loss: 1.2971, Validation Loss: 1.2773
# Epoch [1300/1500], Loss: 1.2965, Validation Loss: 1.2768
# Epoch [1400/1500], Loss: 1.2960, Validation Loss: 1.2764
# Epoch [1500/1500], Loss: 1.2956, Validation Loss: 1.2762
# Training complete!
# Trial 10 completed. Results saved.
# Trial 11
# Epoch [100/1500], Loss: 1.5829, Validation Loss: 1.5552
# Epoch [200/1500], Loss: 1.4559, Validation Loss: 1.4137
# Epoch [300/1500], Loss: 1.4063, Validation Loss: 1.3588
# Epoch [400/1500], Loss: 1.3851, Validation Loss: 1.3355
# Epoch [500/1500], Loss: 1.3736, Validation Loss: 1.3238
# Epoch [600/1500], Loss: 1.3662, Validation Loss: 1.3168
# Epoch [700/1500], Loss: 1.3609, Validation Loss: 1.3123
# Epoch [800/1500], Loss: 1.3569, Validation Loss: 1.3087
# Epoch [900/1500], Loss: 1.3536, Validation Loss: 1.3058
# Epoch [1000/1500], Loss: 1.3512, Validation Loss: 1.3038
# Epoch [1100/1500], Loss: 1.3495, Validation Loss: 1.3022
# Epoch [1200/1500], Loss: 1.3483, Validation Loss: 1.3011
# Epoch [1300/1500], Loss: 1.3475, Validation Loss: 1.3003
# Early stopping at epoch 1353
# Training complete!
# Trial 11 completed. Results saved.
# Trial 12
# Epoch [100/1500], Loss: 1.5572, Validation Loss: 1.5998
# Epoch [200/1500], Loss: 1.4192, Validation Loss: 1.4795
# Epoch [300/1500], Loss: 1.3489, Validation Loss: 1.4225
# Epoch [400/1500], Loss: 1.3212, Validation Loss: 1.4075
# Epoch [500/1500], Loss: 1.3079, Validation Loss: 1.4003
# Epoch [600/1500], Loss: 1.3003, Validation Loss: 1.3973
# Epoch [700/1500], Loss: 1.2954, Validation Loss: 1.3943
# Epoch [800/1500], Loss: 1.2919, Validation Loss: 1.3916
# Epoch [900/1500], Loss: 1.2892, Validation Loss: 1.3886
# Epoch [1000/1500], Loss: 1.2870, Validation Loss: 1.3858
# Epoch [1100/1500], Loss: 1.2852, Validation Loss: 1.3833
# Epoch [1200/1500], Loss: 1.2838, Validation Loss: 1.3812
# Epoch [1300/1500], Loss: 1.2827, Validation Loss: 1.3790
# Epoch [1400/1500], Loss: 1.2817, Validation Loss: 1.3771
# Epoch [1500/1500], Loss: 1.2810, Validation Loss: 1.3750
# Training complete!
# Trial 12 completed. Results saved.
# Trial 13
# Epoch [100/1500], Loss: 1.5711, Validation Loss: 1.5248
# Epoch [200/1500], Loss: 1.4269, Validation Loss: 1.3616
# Epoch [300/1500], Loss: 1.3734, Validation Loss: 1.3070
# Epoch [400/1500], Loss: 1.3503, Validation Loss: 1.2843
# Epoch [500/1500], Loss: 1.3382, Validation Loss: 1.2729
# Epoch [600/1500], Loss: 1.3307, Validation Loss: 1.2664
# Epoch [700/1500], Loss: 1.3255, Validation Loss: 1.2621
# Epoch [800/1500], Loss: 1.3216, Validation Loss: 1.2592
# Epoch [900/1500], Loss: 1.3190, Validation Loss: 1.2572
# Epoch [1000/1500], Loss: 1.3174, Validation Loss: 1.2559
# Epoch [1100/1500], Loss: 1.3163, Validation Loss: 1.2550
# Epoch [1200/1500], Loss: 1.3154, Validation Loss: 1.2545
# Epoch [1300/1500], Loss: 1.3147, Validation Loss: 1.2540
# Epoch [1400/1500], Loss: 1.3141, Validation Loss: 1.2537
# Early stopping at epoch 1495
# Training complete!
# Trial 13 completed. Results saved.
# Trial 14
# Epoch [100/1500], Loss: 1.5649, Validation Loss: 1.5508
# Epoch [200/1500], Loss: 1.4141, Validation Loss: 1.4022
# Epoch [300/1500], Loss: 1.3442, Validation Loss: 1.3354
# Epoch [400/1500], Loss: 1.3164, Validation Loss: 1.3093
# Epoch [500/1500], Loss: 1.3024, Validation Loss: 1.2965
# Epoch [600/1500], Loss: 1.2942, Validation Loss: 1.2896
# Epoch [700/1500], Loss: 1.2888, Validation Loss: 1.2849
# Epoch [800/1500], Loss: 1.2850, Validation Loss: 1.2817
# Epoch [900/1500], Loss: 1.2823, Validation Loss: 1.2791
# Epoch [1000/1500], Loss: 1.2803, Validation Loss: 1.2773
# Epoch [1100/1500], Loss: 1.2786, Validation Loss: 1.2759
# Epoch [1200/1500], Loss: 1.2774, Validation Loss: 1.2746
# Epoch [1300/1500], Loss: 1.2765, Validation Loss: 1.2737
# Epoch [1400/1500], Loss: 1.2758, Validation Loss: 1.2731
# Epoch [1500/1500], Loss: 1.2752, Validation Loss: 1.2726
# Training complete!
# Trial 14 completed. Results saved.
# Trial 15
# Epoch [100/1500], Loss: 1.5778, Validation Loss: 1.5101
# Epoch [200/1500], Loss: 1.4489, Validation Loss: 1.3362
# Epoch [300/1500], Loss: 1.3964, Validation Loss: 1.2659
# Epoch [400/1500], Loss: 1.3744, Validation Loss: 1.2344
# Epoch [500/1500], Loss: 1.3632, Validation Loss: 1.2179
# Epoch [600/1500], Loss: 1.3563, Validation Loss: 1.2082
# Epoch [700/1500], Loss: 1.3517, Validation Loss: 1.2020
# Epoch [800/1500], Loss: 1.3487, Validation Loss: 1.1975
# Epoch [900/1500], Loss: 1.3467, Validation Loss: 1.1945
# Epoch [1000/1500], Loss: 1.3452, Validation Loss: 1.1922
# Epoch [1100/1500], Loss: 1.3442, Validation Loss: 1.1907
# Epoch [1200/1500], Loss: 1.3433, Validation Loss: 1.1895
# Epoch [1300/1500], Loss: 1.3426, Validation Loss: 1.1885
# Epoch [1400/1500], Loss: 1.3420, Validation Loss: 1.1877
# Epoch [1500/1500], Loss: 1.3415, Validation Loss: 1.1870
# Training complete!
# Trial 15 completed. Results saved.
# Trial 16
# Epoch [100/1500], Loss: 1.5456, Validation Loss: 1.5805
# Epoch [200/1500], Loss: 1.4177, Validation Loss: 1.4915
# Epoch [300/1500], Loss: 1.3704, Validation Loss: 1.4562
# Epoch [400/1500], Loss: 1.3509, Validation Loss: 1.4457
# Epoch [500/1500], Loss: 1.3408, Validation Loss: 1.4431
# Epoch [600/1500], Loss: 1.3346, Validation Loss: 1.4420
# Epoch [700/1500], Loss: 1.3305, Validation Loss: 1.4409
# Epoch [800/1500], Loss: 1.3275, Validation Loss: 1.4399
# Early stopping at epoch 826
# Training complete!
# Trial 16 completed. Results saved.
# Trial 17
# Epoch [100/1500], Loss: 1.5622, Validation Loss: 1.5357
# Epoch [200/1500], Loss: 1.4261, Validation Loss: 1.3830
# Epoch [300/1500], Loss: 1.3716, Validation Loss: 1.3232
# Epoch [400/1500], Loss: 1.3485, Validation Loss: 1.2969
# Epoch [500/1500], Loss: 1.3365, Validation Loss: 1.2845
# Epoch [600/1500], Loss: 1.3296, Validation Loss: 1.2772
# Epoch [700/1500], Loss: 1.3254, Validation Loss: 1.2728
# Epoch [800/1500], Loss: 1.3226, Validation Loss: 1.2697
# Epoch [900/1500], Loss: 1.3204, Validation Loss: 1.2673
# Epoch [1000/1500], Loss: 1.3185, Validation Loss: 1.2652
# Epoch [1100/1500], Loss: 1.3168, Validation Loss: 1.2634
# Epoch [1200/1500], Loss: 1.3153, Validation Loss: 1.2619
# Epoch [1300/1500], Loss: 1.3139, Validation Loss: 1.2603
# Epoch [1400/1500], Loss: 1.3125, Validation Loss: 1.2590
# Epoch [1500/1500], Loss: 1.3113, Validation Loss: 1.2581
# Training complete!
# Trial 17 completed. Results saved.
# Trial 18
# Epoch [100/1500], Loss: 1.5851, Validation Loss: 1.6000
# Epoch [200/1500], Loss: 1.4233, Validation Loss: 1.4701
# Epoch [300/1500], Loss: 1.3597, Validation Loss: 1.4266
# Epoch [400/1500], Loss: 1.3329, Validation Loss: 1.4100
# Epoch [500/1500], Loss: 1.3189, Validation Loss: 1.4016
# Epoch [600/1500], Loss: 1.3110, Validation Loss: 1.3972
# Epoch [700/1500], Loss: 1.3059, Validation Loss: 1.3952
# Epoch [800/1500], Loss: 1.3022, Validation Loss: 1.3935
# Epoch [900/1500], Loss: 1.2992, Validation Loss: 1.3922
# Epoch [1000/1500], Loss: 1.2966, Validation Loss: 1.3909
# Epoch [1100/1500], Loss: 1.2945, Validation Loss: 1.3893
# Epoch [1200/1500], Loss: 1.2928, Validation Loss: 1.3876
# Epoch [1300/1500], Loss: 1.2913, Validation Loss: 1.3858
# Epoch [1400/1500], Loss: 1.2900, Validation Loss: 1.3840
# Epoch [1500/1500], Loss: 1.2889, Validation Loss: 1.3816
# Training complete!
# Trial 18 completed. Results saved.
# Trial 19
# Epoch [100/1500], Loss: 1.5322, Validation Loss: 1.5304
# Epoch [200/1500], Loss: 1.3790, Validation Loss: 1.3989
# Epoch [300/1500], Loss: 1.3211, Validation Loss: 1.3443
# Epoch [400/1500], Loss: 1.2962, Validation Loss: 1.3207
# Epoch [500/1500], Loss: 1.2833, Validation Loss: 1.3102
# Epoch [600/1500], Loss: 1.2757, Validation Loss: 1.3042
# Epoch [700/1500], Loss: 1.2707, Validation Loss: 1.3000
# Epoch [800/1500], Loss: 1.2671, Validation Loss: 1.2966
# Epoch [900/1500], Loss: 1.2645, Validation Loss: 1.2934
# Epoch [1000/1500], Loss: 1.2624, Validation Loss: 1.2907
# Epoch [1100/1500], Loss: 1.2609, Validation Loss: 1.2886
# Epoch [1200/1500], Loss: 1.2597, Validation Loss: 1.2868
# Epoch [1300/1500], Loss: 1.2588, Validation Loss: 1.2856
# Epoch [1400/1500], Loss: 1.2581, Validation Loss: 1.2847
# Epoch [1500/1500], Loss: 1.2575, Validation Loss: 1.2839
# Training complete!
# Trial 19 completed. Results saved.
# Trial 20
# Epoch [100/1500], Loss: 1.5751, Validation Loss: 1.5766
# Epoch [200/1500], Loss: 1.4169, Validation Loss: 1.4576
# Epoch [300/1500], Loss: 1.3582, Validation Loss: 1.4197
# Epoch [400/1500], Loss: 1.3338, Validation Loss: 1.4037
# Epoch [500/1500], Loss: 1.3219, Validation Loss: 1.3954
# Epoch [600/1500], Loss: 1.3151, Validation Loss: 1.3916
# Epoch [700/1500], Loss: 1.3106, Validation Loss: 1.3897
# Epoch [800/1500], Loss: 1.3072, Validation Loss: 1.3886
# Early stopping at epoch 858
# Training complete!
# Trial 20 completed. Results saved.
