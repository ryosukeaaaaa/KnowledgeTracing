# %% [markdown]
# ## 時間情報のない集団データ

# %% [markdown]
# ### 方針

# %% [markdown]
# ・内部に問題ごとの依存関係を定義し、その関係をもとに遷移させる。
#
# ・条件付き確率（遷移確率）と周辺分布の積の和から次の周辺分布を求める。
#
# ・まずは遷移過程が部分的にしか分からない人工データを用意し、モデルを学習する。

# %% [markdown]
# ## 人工データ生成

# %%
import numpy as np

# 問題の依存関係の行列 A 
A = np.array([
    [0, 0, 0, 0, 0, 0],  # 初期状態
    [1, 0, 0, 0, 0, 0],  # 問題1は初期状態のみに依存
    [1, 0, 0, 0, 0, 0],  # 問題2は問題1に依存
    [0, 1, 1, 0, 0, 0],  # 問題3は問題2に依存
    [0, 0, 0, 1, 0, 0],  # 問題4は問題2、問題3に依存
    [0, 0, 0, 0, 1, 0]   # 問題4は問題2、問題3に依存
], dtype = float)*3

# 0でない要素の数で割る処理
nonzero_counts = np.count_nonzero(A[1:], axis=1, keepdims=True)
A[1:] = np.where(nonzero_counts != 0, A[1:] / nonzero_counts, 0)

# 遷移確率を計算する関数
def calculate_transition_probabilities(A, X):
    n = len(X)
    raw_probabilities = np.zeros(n)  # 遷移確率の元となる値
    
    # 不正解の問題に対して遷移確率を計算
    for i in range(n):
        if X[i] == 0:  # まだ正解していない問題のみ対象
            required_problems = A[i, :]  # i番目の問題に必要な依存関係
            
            solved_problems = X * required_problems  # 現状解けている
            
            num_solved = np.sum(solved_problems)      # 実際に解けた問題の数
            
            raw_probabilities[i] = np.exp(num_solved)
    
    # 総和で割って正規化
    total_sum = np.sum(raw_probabilities)  # expの総和
    if total_sum > 0:  # 総和が0でなければ正規化
        probabilities = raw_probabilities / total_sum
    else:
        probabilities = raw_probabilities  # 総和が0ならそのまま
    
    return probabilities

# %%
# 教師データセットを生成する関数
def generate_training_data(A, initial_X, num_correct_problems, num_data_per_step):
    n = len(initial_X)  # 問題数
    dataset = []
    
    # 各ステップでデータを生成
    for i in range(1, num_correct_problems+1):  # 1問以上の正解を対象にする
        for j in range(num_data_per_step):  # 各ステップごとにデータ数
            X = initial_X.copy()  # 初期状態からスタート
            
            # i問正解させる
            for k in range(i):
                input_X = X.copy()    # 遷移前状態を保持
                probabilities = calculate_transition_probabilities(A, X)
                
                if np.sum(probabilities) > 0:  # 正規化された確率がある場合
                    # 確率に基づいて次に正解させる問題を選択
                    next_correct_problem = np.random.choice(n, p=probabilities)
                    X[next_correct_problem] = 1  # 選ばれた問題を正解に遷移させる
            
                # 初期状態と1ステップ後の状態の差分を教師データとして使用
                target_Y = (X - input_X).clip(min=0)  # 0から1に変わった部分のみを1、他は0
                
                # 初期状態（入力）と差分（教師データ）のペアを保存
                dataset.append((input_X.copy(), target_Y.copy()))  # (入力データ, 教師データ)
    
    return dataset

# %%
import torch

import itertools
from collections import defaultdict

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
def _bcsoftmax1d(x, budget):
    """Budget Constrained Softmax function for vector.

    Args:
        x (Tensor): input vector. shape: (n_outputs, )
        budget (Tensor): budget (constraint) vector. shape: (n_outputs, )

    Returns:
        y (Tensor): output probability vector. shape: (n_outputs, ). Satisfying the constraints y_i <= budget_i.
    
    """
    x = x - torch.max(x, dim=0)[0] # normalization to avoid numerical errors
    exp_x = torch.exp(x)
    # sorting
    _, indices = torch.sort(budget / exp_x, descending=False)
    exp_x = exp_x[indices]
    budget = budget[indices]
    # find K_B
    r = torch.flip(torch.cumsum(torch.flip(exp_x, dims=(0, )), dim=0), dims=(0, ))
    s = 1.0 - (torch.cumsum(budget, dim=0) - budget)
    z = r / s
    is_in_KB = torch.logical_and(
        (s - budget) > 0, exp_x / z > budget
    )
    # compute outputs
    s = 1 - torch.sum(budget * is_in_KB)
    r = torch.sum(exp_x * (~is_in_KB))
    y = torch.where(~is_in_KB, s * exp_x / r, budget)
    # undo sorting
    _, inv_indices = torch.sort(indices, descending=False)
    return y[inv_indices]


def _bcsoftmax1d_stable(x, budget):
    """Budget Constrained Softmax function for vector.
    This function is more numerically stable than `_bcsoftmax1d` by computing some values in log-scale.
    
    Args:
        x (Tensor): input vector. shape: (n_outputs, )
        budget (Tensor): budget (constraint) vector. shape: (n_outputs, )

    Returns:
        y (Tensor): output probability vector. shape: (n_outputs, ). Satisfying the constraints y_i <= budget_i.
    
    """
    # sorting
    _, indices = torch.sort(torch.log(budget) - x, descending=False)
    x = x[indices]
    budget = budget[indices]
    # find K_B
    log_r = torch.flip(torch.logcumsumexp(torch.flip(x, dims=(0, )), dim=0), dims=(0, ))
    s = 1.0 - (torch.cumsum(budget, dim=0) - budget)
    is_in_KB = torch.logical_or(
        budget == 0,
        torch.logical_and(
            s - budget > 0,
            x - log_r + torch.log(s) > torch.log(budget)
        )
    )
    # compute outputs
    exp_x = torch.exp(x - torch.max(torch.where(~is_in_KB, x, -torch.inf), dim=0)[0])
    s = 1 - torch.sum(budget * is_in_KB)
    r = torch.sum(exp_x * (~is_in_KB))
    y = torch.where(~is_in_KB, s * exp_x / r, budget)
    # undo sorting
    _, inv_indices = torch.sort(indices, descending=False)
    return y[inv_indices]


class BCSoftmax1d(torch.autograd.Function):
    """Autograd implementation of Budget Constrained Softmax function for vector.
    """
    generate_vmap_rule = True
    
    @staticmethod
    def forward(x, c):
        y = _bcsoftmax1d_stable(x, c)
        return y

    @staticmethod
    def setup_context(ctx, inputs, output):
        x, c = inputs
        is_in_KB = c == output
        ctx.save_for_backward(x, c, is_in_KB)
    
    @staticmethod
    def backward(ctx, grad_y):
        x, c, is_in_KB = ctx.saved_tensors
        exp_x = torch.exp(
            x - torch.max(torch.where(~is_in_KB, x, -torch.inf), dim=0)[0]
        )
        s = 1 - torch.sum(c * is_in_KB)
        r = torch.sum(exp_x * (~is_in_KB))
        
        # compute Jacobian
        Jx = torch.where(
            torch.outer(~is_in_KB, ~is_in_KB),
            torch.diag(~is_in_KB * exp_x) * r - torch.outer(exp_x, exp_x),
            0,
        )
        Jx *= torch.where(
            s > 0,
            s / (r * r),
            0
        )
        Jc = torch.where(
            torch.outer(~is_in_KB, is_in_KB),
            - exp_x[:, None] / r,
            1.0 * torch.diag(is_in_KB)
        )

        # print("s", s, "r", r)
        # print("勾配", torch.matmul(grad_y, Jx), torch.matmul(grad_y, Jc))
        assert not torch.isnan(torch.matmul(grad_y, Jx)).any(), "Jx contains NaN"
        assert not torch.isinf(torch.matmul(grad_y, Jx)).any(), "Jx contains Inf"
        assert not torch.isnan(torch.matmul(grad_y, Jc)).any(), "Jc contains NaN"
        assert not torch.isinf(torch.matmul(grad_y, Jc)).any(), "Jc contains Inf"

        # return vector-Jacobian product
        return torch.matmul(grad_y, Jx), torch.matmul(grad_y, Jc)

# %%
######### Use these functions! #########
bcsoftmax1d = BCSoftmax1d.apply

# データによってmodelを通す回数が違
# bcsoftmax2d = torch.vmap(BCSoftmax1d.apply) # input shape = (batch_size, n_classes)

# %%
class Model(nn.Module):
    def __init__(self, num_questions):
        super(Model, self).__init__()
        self.fc = nn.Linear(num_questions, num_questions, bias=False)  # 全結合層

    def forward(self, x, c):
        x = self.fc(x)  # 全結合層の適用
        x = bcsoftmax1d(x, c)
        return x

# %%
"評価指標"

def kl_divergence(p, q, epsilon=1e-10):
    """
    KLダイバージェンスを計算する関数（qが0の場合の無限大問題を回避）
    
    Parameters:
        p (numpy.ndarray): 真の確率分布
        q (numpy.ndarray): 予測確率分布
        epsilon (float): スムージングパラメータ（非常に小さい値）
    
    Returns:
        float: KLダイバージェンス
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)
    
    # pとqにスムージングを適用
    p = np.where(p == 0, epsilon, p)
    q = np.where(q == 0, epsilon, q)
    
    # KLダイバージェンスの計算
    return np.sum(p * np.log(p / q))

def hellinger_distance(p, q):
    """
    Hellinger距離を計算する関数

    Parameters:
        p (numpy.ndarray): 真の分布 [batch_size, num_classes]
        q (numpy.ndarray): 予測分布 [batch_size, num_classes]
    
    Returns:
        float: Hellinger距離の平均値
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)
    # Hellinger距離の計算式: H(p, q) = (1/√2) * ||√p - √q||_2
    sqrt_p = np.sqrt(p)
    sqrt_q = np.sqrt(q)
    distance = np.sqrt(np.sum((sqrt_p - sqrt_q) ** 2)) / np.sqrt(2)
    return np.mean(distance)

def jensen_shannon_divergence(p, q):
    """
    Jensen-Shannon divergence を計算する関数

    Parameters:
        p (numpy.ndarray): 真の分布 [batch_size, num_classes]
        q (numpy.ndarray): 予測分布 [batch_size, num_classes]
    
    Returns:
        float: Jensen-Shannon divergence の平均値
    """
    p = np.array(p, dtype=np.float64)
    q = np.array(q, dtype=np.float64)

    # 0 の値があると log(0) が発生するため、微小値を加える
    epsilon = 1e-12
    p = np.clip(p, epsilon, 1)
    q = np.clip(q, epsilon, 1)
    
    # 分布の平均 M
    m = 0.5 * (p + q)
    
    # Kullback-Leibler divergence の補助関数
    def kl(a, b):
        return np.sum(a * np.log(a / b))
    
    # JSD の計算: JSD(p || q) = 0.5 * (KL(p || M) + KL(q || M))
    jsd = 0.5 * (kl(p, m) + kl(q, m))
    
    # 各サンプルの平均を返す
    return np.mean(jsd)


def evaluate_model(r, p, q):
    """
    遷移確率の真値と予測値の類似性を評価する関数
    :param r: 各ノードの重み (np.array)
    :param p: 各ノードの真の遷移確率 (2D np.array: ノード数 x 遷移確率)
    :param q: 各ノードの予測遷移確率 (2D np.array: ノード数 x 遷移確率)
    :return: 評価指標 L
    """
    L = 0
    for k in range(len(r)):
        L += r[k] * kl_divergence(p[k], q[k])
    return L

# %%
# データセットの生成
num_questions = 5  # 問題数
num_data_per_step = 100     # 各ステップごとに生成するデータ数

num_epochs = 1500  # エポック数
alpha = 0.001 # 正則化パラメータ
early_stopping_patience = 10  # Early Stopping の patience

split_ratio = 0.8  # 学習データと検証データの分割比率

# %%
"実験結果を保存する外部ファイル"
import csv
from datetime import datetime

# 今日の日付を "YYYY-MM-DD" 形式で取得
today = datetime.now().strftime("%Y-%m-%d")

# ファイル名に日付を含める
results_csv = f"results_allpath_{today}_{num_questions}_{num_data_per_step}_{num_data_per_step}_{split_ratio}.csv"

# 初回にヘッダーを追加する
header = [
    "Iteration", 
    "KL_Model_allpath",
    "HD_Model_allpath",
    "JSD_Model_allpath",
]

try:
    with open(results_csv, "x", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(header)
except FileExistsError:
    pass  # ファイルが既に存在する場合は何もしない

# %%
for trial in range(20):
    print(f"Trial {trial + 1}")

    "データ生成"

    # 生徒の回答状況 X (1が正解、0が不正解)
    # 初期状態は全て不正解
    X_init = np.array([1, 0, 0, 0, 0, 0])

    training_data = generate_training_data(A, X_init, num_questions, num_data_per_step)
    train_X = [input_data for input_data, _ in training_data]
    train_Y = [target_data for _, target_data in training_data]

    
    # データをトレーニングと検証に分割（正解数のバランスが良くなるように分割）
    # 8:2に分割
    def split_balanced_data(train_X, train_Y, ratio=0.8):
        data_per_correct_count = defaultdict(list)
        for x, y in zip(train_X, train_Y):
            correct_count = sum(y)
            data_per_correct_count[correct_count].append((x, y))

        train_X_data, train_Y_data, val_X_data, val_Y_data = [], [], [], []
        for correct_count, data in data_per_correct_count.items():
            split_index = int(len(data) * ratio)
            train_data = data[:split_index]
            val_data = data[split_index:]
            train_X_data.extend([x for x, y in train_data])
            train_Y_data.extend([y for x, y in train_data])
            val_X_data.extend([x for x, y in val_data])
            val_Y_data.extend([y for x, y in val_data])

        return train_X_data, train_Y_data, val_X_data, val_Y_data

    train_X_data, train_Y_data, val_X_data, val_Y_data = split_balanced_data(train_X, train_Y, split_ratio)

    # PyTorch テンソルに変換
    train_X = torch.tensor(train_X_data, dtype=torch.float32)
    train_Y = torch.tensor(train_Y_data, dtype=torch.float32)
    val_X = torch.tensor(val_X_data, dtype=torch.float32)
    val_Y = torch.tensor(val_Y_data, dtype=torch.float32)

    "状態定義"

    # Generate states where the first digit is always 1
    states = [(1,) + state for state in itertools.product([0, 1], repeat=num_questions)]

    states = sorted(states, key=lambda state: sum(state))

    # Initialize the state counts
    state_counts = defaultdict(int)

    # Assuming 'dataset' is your list of student results
    for result, result2 in training_data:
        # print(result2)
        state_tuple = tuple(map(int, result + result2))  # Convert np.int64 to int
        state_counts[state_tuple] += 1  # Count only if the first digit is 1

    # Display the counts for each state
    for state in states:
        count = state_counts[state]
        formatted_state = list(state)  # Convert tuple to list for the desired format

    "モデル定義"
    # モデル、損失関数、最適化関数の設定
    model = Model(num_questions+1)  # 5問+初期状態の問題を扱うモデル
    criterion = nn.CrossEntropyLoss()  # クロスエントロピー損失
    optimizer = optim.Adam(model.parameters(), lr=0.01)

    "学習"
    best_val_loss = float('inf')
    early_stopping_counter = 0

    for epoch in range(num_epochs):
        model.train()  # モデルを訓練モードに
        optimizer.zero_grad()  # 勾配の初期化
        
        outputs = []  # 出力を保持するリスト
        # 各データに対して train_Y の値に基づいてループを実行
        for i, target in enumerate(train_Y):
            c = torch.ones(num_questions+1, dtype=torch.float32)
            output = train_X[i]  # 各 i 番目の入力データを使用
            output = output.view(-1)

            # もしcの和が1なら、rが0となるので対応
            if c.sum() <= 1:
                # print("aaaaaaaa")
                output = c
            else:
                output = model(output, c)  # 前回の出力を次のステップの入力として使用

            outputs.append(output)  # 最終的な出力を保存

        # outputs を適切な形に変換して損失計算（例えば torch.stack を使用）
        outputs = torch.stack(outputs)
        outputs = outputs.squeeze(1)

        # モデルの出力の確認
        assert not torch.isnan(outputs).any(), "Model output contains NaN"
        assert not torch.isinf(outputs).any(), "Model output contains Inf"

        # L1正則化項の計算
        l1_reg = torch.tensor(0.0, requires_grad=True)
        for param in model.parameters():
            l1_reg = l1_reg + torch.sum(torch.abs(param))

        # 損失の計算
        loss0 = criterion(outputs, train_Y)

        loss = loss0 + alpha * l1_reg  # L1正則化項を追加した損失

        # 損失の確認
        assert not torch.isnan(loss).any(), "Loss contains NaN"
        assert not torch.isinf(loss).any(), "Loss contains Inf"

        # バックプロパゲーションとパラメータの更新
        loss.backward()
        optimizer.step()

        # 検証フェーズ
        model.eval()  # モデルを評価モードに
        with torch.no_grad():
            val_outputs = []
            for i, target in enumerate(val_Y):
                c = torch.cat([torch.tensor([0.0]), torch.ones(num_questions, dtype=torch.float32)])
                output = val_X[i]  # 各 i 番目の入力データを使用
                output = output.view(-1)
                for _ in range(int(sum(target))):
                    if c.sum() <= 1:
                        output_0 = c
                    else:
                        output_0 = model(output, c)
                    output = output_0 + output
                    c = c - output_0
                val_outputs.append(output - val_X[i])

            val_outputs = torch.stack(val_outputs)
            val_outputs = val_outputs.squeeze(1)
            val_loss0 = criterion(val_outputs, val_Y)
            val_loss = val_loss0 + alpha * l1_reg

        # Early Stopping の処理
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stopping_counter = 0
        else:
            early_stopping_counter += 1

        if early_stopping_counter >= early_stopping_patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

        # 100エポックごとに損失を表示
        if (epoch+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Validation Loss: {val_loss.item():.4f}')

    # 学習結果の確認
    print("Training complete!")

    "モデル評価"
    node_probabilities = defaultdict(float)
    start = (1,) + tuple(0 for _ in range(num_questions))
    node_probabilities[start] = 1

    # 機械学習モデルと簡易モデル
    KL = 0
    HD = 0
    JSD = 0

    for state in states:
        probabilities = calculate_transition_probabilities(A, np.array(state))

        # 最下層から頂点までのノードの分布を順に計算
        for i in range(num_questions + 1):
            if state[i] == 0:  # まだ解けていない問題
                # 遷移後の状態
                next_state = list(state)
                next_state[i] = 1
                next_state = tuple(next_state)
                node_probabilities[next_state] += probabilities[i] * node_probabilities[state]
        
        # budgetの計算
        c_g = torch.ones(num_questions+1, dtype=torch.float32)
        c_g = c_g - torch.tensor(state, dtype=torch.float32)

        # 状態とその予測分布
        state_tensor = torch.tensor(state, dtype=torch.float32)
        predicted_values = model(state_tensor, c_g)  # 予測値を計算

    # 評価指標の計算
        kl = node_probabilities[state] * kl_divergence(probabilities, predicted_values.detach())
        hd = node_probabilities[state] * hellinger_distance(probabilities, predicted_values.detach())
        jsd = node_probabilities[state] * jensen_shannon_divergence(probabilities, predicted_values.detach())
        # print(f"状態: {state}, ノード分布: {node_probabilities[state]:.3g}, KL: {kl:.3g}, HD: {hd:.3g}, JSD: {jsd:.3g}")
        # print(f"真の遷移確率: {probabilities}, 予測遷移確率: {predicted_values}")
        KL += kl
        HD += hd
        JSD += jsd


    # 試行ごとの指標をCSVに追記
    with open(results_csv, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([
            trial + 1,
            KL,
            HD,
            JSD
        ])

    print(f"Trial {trial + 1} completed. Results saved.")
# Out:
# Trial 1
# /var/folders/zg/773ptkr55z99zw26dvy19_v00000gn/T/ipykernel_29230/4066109522.py:38: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   train_X = torch.tensor(train_X_data, dtype=torch.float32)
# Epoch [100/1500], Loss: 1.5882, Validation Loss: 1.6076
# Epoch [200/1500], Loss: 1.4845, Validation Loss: 1.5230
# Epoch [300/1500], Loss: 1.4500, Validation Loss: 1.4939
# Epoch [400/1500], Loss: 1.4356, Validation Loss: 1.4817
# Epoch [500/1500], Loss: 1.4282, Validation Loss: 1.4754
# Epoch [600/1500], Loss: 1.4239, Validation Loss: 1.4728
# Epoch [700/1500], Loss: 1.4210, Validation Loss: 1.4716
# Epoch [800/1500], Loss: 1.4191, Validation Loss: 1.4713
# Early stopping at epoch 801
# Training complete!
# Trial 1 completed. Results saved.
# Trial 2
# Epoch [100/1500], Loss: 1.5970, Validation Loss: 1.6142
# Epoch [200/1500], Loss: 1.4952, Validation Loss: 1.5253
# Epoch [300/1500], Loss: 1.4617, Validation Loss: 1.4944
# Epoch [400/1500], Loss: 1.4478, Validation Loss: 1.4802
# Epoch [500/1500], Loss: 1.4399, Validation Loss: 1.4687
# Epoch [600/1500], Loss: 1.4356, Validation Loss: 1.4608
# Epoch [700/1500], Loss: 1.4239, Validation Loss: 1.3594
# Epoch [800/1500], Loss: 1.4193, Validation Loss: 1.3508
# Epoch [900/1500], Loss: 1.4167, Validation Loss: 1.3457
# Epoch [1000/1500], Loss: 1.4150, Validation Loss: 1.3426
# Epoch [1100/1500], Loss: 1.4137, Validation Loss: 1.3403
# Epoch [1200/1500], Loss: 1.4127, Validation Loss: 1.3392
# Epoch [1300/1500], Loss: 1.4120, Validation Loss: 1.3383
# Epoch [1400/1500], Loss: 1.4113, Validation Loss: 1.3376
# Epoch [1500/1500], Loss: 1.4108, Validation Loss: 1.3369
# Training complete!
# Trial 2 completed. Results saved.
# Trial 3
# Epoch [100/1500], Loss: 1.5994, Validation Loss: 1.6109
# Epoch [200/1500], Loss: 1.5044, Validation Loss: 1.5212
# Epoch [300/1500], Loss: 1.4715, Validation Loss: 1.4879
# Epoch [400/1500], Loss: 1.4577, Validation Loss: 1.4738
# Epoch [500/1500], Loss: 1.4509, Validation Loss: 1.4674
# Epoch [600/1500], Loss: 1.4473, Validation Loss: 1.4643
# Epoch [700/1500], Loss: 1.4450, Validation Loss: 1.4621
# Epoch [800/1500], Loss: 1.4434, Validation Loss: 1.4598
# Epoch [900/1500], Loss: 1.4421, Validation Loss: 1.4572
# Epoch [1000/1500], Loss: 1.4412, Validation Loss: 1.4547
# Epoch [1100/1500], Loss: 1.4404, Validation Loss: 1.4525
# Epoch [1200/1500], Loss: 1.4397, Validation Loss: 1.4500
# Epoch [1300/1500], Loss: 1.4391, Validation Loss: 1.4471
# Epoch [1400/1500], Loss: 1.4383, Validation Loss: 1.4407
# Epoch [1500/1500], Loss: 1.4272, Validation Loss: 1.3429
# Training complete!
# Trial 3 completed. Results saved.
# Trial 4
# Epoch [100/1500], Loss: 1.6071, Validation Loss: 1.6203
# Epoch [200/1500], Loss: 1.4989, Validation Loss: 1.4971
# Epoch [300/1500], Loss: 1.4461, Validation Loss: 1.3624
# Epoch [400/1500], Loss: 1.4285, Validation Loss: 1.3387
# Epoch [500/1500], Loss: 1.4205, Validation Loss: 1.3267
# Epoch [600/1500], Loss: 1.4161, Validation Loss: 1.3187
# Epoch [700/1500], Loss: 1.4131, Validation Loss: 1.3131
# Epoch [800/1500], Loss: 1.4108, Validation Loss: 1.3087
# Epoch [900/1500], Loss: 1.4090, Validation Loss: 1.3051
# Epoch [1000/1500], Loss: 1.4074, Validation Loss: 1.3022
# Epoch [1100/1500], Loss: 1.4060, Validation Loss: 1.3000
# Epoch [1200/1500], Loss: 1.4049, Validation Loss: 1.2982
# Epoch [1300/1500], Loss: 1.4038, Validation Loss: 1.2967
# Early stopping at epoch 1376
# Training complete!
# Trial 4 completed. Results saved.
# Trial 5
# Epoch [100/1500], Loss: 1.5933, Validation Loss: 1.6357
# Epoch [200/1500], Loss: 1.4918, Validation Loss: 1.5415
# Epoch [300/1500], Loss: 1.4579, Validation Loss: 1.5107
# Epoch [400/1500], Loss: 1.4449, Validation Loss: 1.4996
# Epoch [500/1500], Loss: 1.4388, Validation Loss: 1.4947
# Epoch [600/1500], Loss: 1.4354, Validation Loss: 1.4924
# Epoch [700/1500], Loss: 1.4333, Validation Loss: 1.4908
# Epoch [800/1500], Loss: 1.4317, Validation Loss: 1.4894
# Epoch [900/1500], Loss: 1.4304, Validation Loss: 1.4880
# Epoch [1000/1500], Loss: 1.4292, Validation Loss: 1.4864
# Epoch [1100/1500], Loss: 1.4281, Validation Loss: 1.4843
# Epoch [1200/1500], Loss: 1.4270, Validation Loss: 1.4813
# Epoch [1300/1500], Loss: 1.4259, Validation Loss: 1.4759
# Epoch [1400/1500], Loss: 1.4092, Validation Loss: 1.3741
# Epoch [1500/1500], Loss: 1.4057, Validation Loss: 1.3717
# Training complete!
# Trial 5 completed. Results saved.
# Trial 6
# Epoch [100/1500], Loss: 1.6030, Validation Loss: 1.5975
# Epoch [200/1500], Loss: 1.4992, Validation Loss: 1.4859
# Epoch [300/1500], Loss: 1.4526, Validation Loss: 1.3590
# Epoch [400/1500], Loss: 1.4369, Validation Loss: 1.3353
# Epoch [500/1500], Loss: 1.4290, Validation Loss: 1.3240
# Epoch [600/1500], Loss: 1.4241, Validation Loss: 1.3169
# Epoch [700/1500], Loss: 1.4208, Validation Loss: 1.3120
# Epoch [800/1500], Loss: 1.4183, Validation Loss: 1.3083
# Epoch [900/1500], Loss: 1.4166, Validation Loss: 1.3053
# Epoch [1000/1500], Loss: 1.4154, Validation Loss: 1.3037
# Epoch [1100/1500], Loss: 1.4146, Validation Loss: 1.3026
# Epoch [1200/1500], Loss: 1.4139, Validation Loss: 1.3018
# Epoch [1300/1500], Loss: 1.4134, Validation Loss: 1.3011
# Epoch [1400/1500], Loss: 1.4130, Validation Loss: 1.3005
# Early stopping at epoch 1412
# Training complete!
# Trial 6 completed. Results saved.
# Trial 7
# Epoch [100/1500], Loss: 1.6028, Validation Loss: 1.6347
# Epoch [200/1500], Loss: 1.4880, Validation Loss: 1.5375
# Epoch [300/1500], Loss: 1.4478, Validation Loss: 1.5013
# Epoch [400/1500], Loss: 1.4335, Validation Loss: 1.4883
# Epoch [500/1500], Loss: 1.4267, Validation Loss: 1.4792
# Early stopping at epoch 595
# Training complete!
# Trial 7 completed. Results saved.
# Trial 8
# Epoch [100/1500], Loss: 1.5892, Validation Loss: 1.6108
# Epoch [200/1500], Loss: 1.4781, Validation Loss: 1.5154
# Epoch [300/1500], Loss: 1.4442, Validation Loss: 1.4852
# Epoch [400/1500], Loss: 1.4300, Validation Loss: 1.4717
# Epoch [500/1500], Loss: 1.4225, Validation Loss: 1.4635
# Epoch [600/1500], Loss: 1.4185, Validation Loss: 1.4598
# Epoch [700/1500], Loss: 1.4161, Validation Loss: 1.4577
# Epoch [800/1500], Loss: 1.4145, Validation Loss: 1.4561
# Epoch [900/1500], Loss: 1.4133, Validation Loss: 1.4545
# Epoch [1000/1500], Loss: 1.4123, Validation Loss: 1.4524
# Epoch [1100/1500], Loss: 1.4114, Validation Loss: 1.4496
# Epoch [1200/1500], Loss: 1.4103, Validation Loss: 1.4430
# Epoch [1300/1500], Loss: 1.3971, Validation Loss: 1.3456
# Epoch [1400/1500], Loss: 1.3946, Validation Loss: 1.3402
# Epoch [1500/1500], Loss: 1.3934, Validation Loss: 1.3389
# Training complete!
# Trial 8 completed. Results saved.
# Trial 9
# Epoch [100/1500], Loss: 1.5717, Validation Loss: 1.5905
# Epoch [200/1500], Loss: 1.4812, Validation Loss: 1.4724
# Epoch [300/1500], Loss: 1.4457, Validation Loss: 1.4057
# Epoch [400/1500], Loss: 1.4324, Validation Loss: 1.3888
# Epoch [500/1500], Loss: 1.4257, Validation Loss: 1.3810
# Epoch [600/1500], Loss: 1.4217, Validation Loss: 1.3763
# Epoch [700/1500], Loss: 1.4189, Validation Loss: 1.3732
# Epoch [800/1500], Loss: 1.4169, Validation Loss: 1.3708
# Epoch [900/1500], Loss: 1.4154, Validation Loss: 1.3690
# Epoch [1000/1500], Loss: 1.4142, Validation Loss: 1.3678
# Epoch [1100/1500], Loss: 1.4133, Validation Loss: 1.3668
# Epoch [1200/1500], Loss: 1.4124, Validation Loss: 1.3662
# Epoch [1300/1500], Loss: 1.4117, Validation Loss: 1.3656
# Epoch [1400/1500], Loss: 1.4110, Validation Loss: 1.3653
# Epoch [1500/1500], Loss: 1.4104, Validation Loss: 1.3649
# Training complete!
# Trial 9 completed. Results saved.
# Trial 10
# Epoch [100/1500], Loss: 1.5917, Validation Loss: 1.6019
# Epoch [200/1500], Loss: 1.5031, Validation Loss: 1.5199
# Epoch [300/1500], Loss: 1.4722, Validation Loss: 1.4920
# Epoch [400/1500], Loss: 1.4596, Validation Loss: 1.4793
# Epoch [500/1500], Loss: 1.4534, Validation Loss: 1.4733
# Epoch [600/1500], Loss: 1.4496, Validation Loss: 1.4694
# Epoch [700/1500], Loss: 1.4471, Validation Loss: 1.4666
# Epoch [800/1500], Loss: 1.4452, Validation Loss: 1.4644
# Epoch [900/1500], Loss: 1.4438, Validation Loss: 1.4624
# Epoch [1000/1500], Loss: 1.4426, Validation Loss: 1.4602
# Epoch [1100/1500], Loss: 1.4415, Validation Loss: 1.4580
# Epoch [1200/1500], Loss: 1.4405, Validation Loss: 1.4553
# Epoch [1300/1500], Loss: 1.4382, Validation Loss: 1.4272
# Epoch [1400/1500], Loss: 1.4276, Validation Loss: 1.3412
# Epoch [1500/1500], Loss: 1.4260, Validation Loss: 1.3388
# Training complete!
# Trial 10 completed. Results saved.
# Trial 11
# Epoch [100/1500], Loss: 1.5889, Validation Loss: 1.5880
# Epoch [200/1500], Loss: 1.4916, Validation Loss: 1.4965
# Epoch [300/1500], Loss: 1.4574, Validation Loss: 1.4611
# Epoch [400/1500], Loss: 1.4433, Validation Loss: 1.4482
# Epoch [500/1500], Loss: 1.4360, Validation Loss: 1.4416
# Epoch [600/1500], Loss: 1.4317, Validation Loss: 1.4373
# Epoch [700/1500], Loss: 1.4289, Validation Loss: 1.4344
# Epoch [800/1500], Loss: 1.4270, Validation Loss: 1.4327
# Epoch [900/1500], Loss: 1.4256, Validation Loss: 1.4314
# Epoch [1000/1500], Loss: 1.4245, Validation Loss: 1.4302
# Epoch [1100/1500], Loss: 1.4235, Validation Loss: 1.4289
# Epoch [1200/1500], Loss: 1.4226, Validation Loss: 1.4274
# Epoch [1300/1500], Loss: 1.4218, Validation Loss: 1.4257
# Epoch [1400/1500], Loss: 1.4211, Validation Loss: 1.4239
# Epoch [1500/1500], Loss: 1.4205, Validation Loss: 1.4223
# Training complete!
# Trial 11 completed. Results saved.
# Trial 12
# Epoch [100/1500], Loss: 1.5949, Validation Loss: 1.5631
# Epoch [200/1500], Loss: 1.4822, Validation Loss: 1.4128
# Epoch [300/1500], Loss: 1.4437, Validation Loss: 1.3599
# Epoch [400/1500], Loss: 1.4280, Validation Loss: 1.3382
# Epoch [500/1500], Loss: 1.4200, Validation Loss: 1.3271
# Epoch [600/1500], Loss: 1.4153, Validation Loss: 1.3206
# Epoch [700/1500], Loss: 1.4121, Validation Loss: 1.3160
# Epoch [800/1500], Loss: 1.4098, Validation Loss: 1.3120
# Epoch [900/1500], Loss: 1.4080, Validation Loss: 1.3096
# Epoch [1000/1500], Loss: 1.4066, Validation Loss: 1.3075
# Epoch [1100/1500], Loss: 1.4055, Validation Loss: 1.3057
# Early stopping at epoch 1194
# Training complete!
# Trial 12 completed. Results saved.
# Trial 13
# Epoch [100/1500], Loss: 1.5851, Validation Loss: 1.5852
# Epoch [200/1500], Loss: 1.4850, Validation Loss: 1.4536
# Epoch [300/1500], Loss: 1.4461, Validation Loss: 1.3847
# Epoch [400/1500], Loss: 1.4310, Validation Loss: 1.3627
# Epoch [500/1500], Loss: 1.4235, Validation Loss: 1.3514
# Epoch [600/1500], Loss: 1.4190, Validation Loss: 1.3445
# Epoch [700/1500], Loss: 1.4160, Validation Loss: 1.3399
# Epoch [800/1500], Loss: 1.4138, Validation Loss: 1.3367
# Epoch [900/1500], Loss: 1.4122, Validation Loss: 1.3344
# Epoch [1000/1500], Loss: 1.4108, Validation Loss: 1.3329
# Epoch [1100/1500], Loss: 1.4098, Validation Loss: 1.3313
# Epoch [1200/1500], Loss: 1.4090, Validation Loss: 1.3301
# Epoch [1300/1500], Loss: 1.4085, Validation Loss: 1.3292
# Epoch [1400/1500], Loss: 1.4080, Validation Loss: 1.3286
# Epoch [1500/1500], Loss: 1.4075, Validation Loss: 1.3280
# Training complete!
# Trial 13 completed. Results saved.
# Trial 14
# Epoch [100/1500], Loss: 1.5908, Validation Loss: 1.5884
# Epoch [200/1500], Loss: 1.4929, Validation Loss: 1.5045
# Epoch [300/1500], Loss: 1.4609, Validation Loss: 1.4716
# Epoch [400/1500], Loss: 1.4411, Validation Loss: 1.3748
# Epoch [500/1500], Loss: 1.4316, Validation Loss: 1.3532
# Epoch [600/1500], Loss: 1.4268, Validation Loss: 1.3441
# Epoch [700/1500], Loss: 1.4239, Validation Loss: 1.3380
# Epoch [800/1500], Loss: 1.4220, Validation Loss: 1.3337
# Epoch [900/1500], Loss: 1.4207, Validation Loss: 1.3305
# Epoch [1000/1500], Loss: 1.4198, Validation Loss: 1.3284
# Epoch [1100/1500], Loss: 1.4192, Validation Loss: 1.3264
# Epoch [1200/1500], Loss: 1.4186, Validation Loss: 1.3252
# Epoch [1300/1500], Loss: 1.4181, Validation Loss: 1.3244
# Epoch [1400/1500], Loss: 1.4177, Validation Loss: 1.3235
# Epoch [1500/1500], Loss: 1.4173, Validation Loss: 1.3229
# Training complete!
# Trial 14 completed. Results saved.
# Trial 15
# Epoch [100/1500], Loss: 1.5964, Validation Loss: 1.6136
# Epoch [200/1500], Loss: 1.5074, Validation Loss: 1.5257
# Epoch [300/1500], Loss: 1.4776, Validation Loss: 1.4927
# Epoch [400/1500], Loss: 1.4649, Validation Loss: 1.4774
# Epoch [500/1500], Loss: 1.4586, Validation Loss: 1.4701
# Epoch [600/1500], Loss: 1.4551, Validation Loss: 1.4662
# Epoch [700/1500], Loss: 1.4528, Validation Loss: 1.4636
# Epoch [800/1500], Loss: 1.4510, Validation Loss: 1.4616
# Epoch [900/1500], Loss: 1.4496, Validation Loss: 1.4600
# Epoch [1000/1500], Loss: 1.4484, Validation Loss: 1.4584
# Epoch [1100/1500], Loss: 1.4474, Validation Loss: 1.4568
# Epoch [1200/1500], Loss: 1.4464, Validation Loss: 1.4548
# Epoch [1300/1500], Loss: 1.4456, Validation Loss: 1.4527
# Epoch [1400/1500], Loss: 1.4449, Validation Loss: 1.4497
# Epoch [1500/1500], Loss: 1.4324, Validation Loss: 1.3483
# Training complete!
# Trial 15 completed. Results saved.
# Trial 16
# Epoch [100/1500], Loss: 1.5739, Validation Loss: 1.5855
# Epoch [200/1500], Loss: 1.4882, Validation Loss: 1.5042
# Epoch [300/1500], Loss: 1.4590, Validation Loss: 1.4738
# Epoch [400/1500], Loss: 1.4469, Validation Loss: 1.4613
# Epoch [500/1500], Loss: 1.4406, Validation Loss: 1.4548
# Epoch [600/1500], Loss: 1.4368, Validation Loss: 1.4507
# Epoch [700/1500], Loss: 1.4342, Validation Loss: 1.4477
# Epoch [800/1500], Loss: 1.4323, Validation Loss: 1.4451
# Epoch [900/1500], Loss: 1.4309, Validation Loss: 1.4428
# Epoch [1000/1500], Loss: 1.4297, Validation Loss: 1.4403
# Epoch [1100/1500], Loss: 1.4285, Validation Loss: 1.4337
# Early stopping at epoch 1165
# Training complete!
# Trial 16 completed. Results saved.
# Trial 17
# Epoch [100/1500], Loss: 1.5986, Validation Loss: 1.6189
# Epoch [200/1500], Loss: 1.4847, Validation Loss: 1.4525
# Epoch [300/1500], Loss: 1.4447, Validation Loss: 1.3902
# Epoch [400/1500], Loss: 1.4308, Validation Loss: 1.3705
# Epoch [500/1500], Loss: 1.4243, Validation Loss: 1.3617
# Epoch [600/1500], Loss: 1.4207, Validation Loss: 1.3570
# Epoch [700/1500], Loss: 1.4184, Validation Loss: 1.3543
# Epoch [800/1500], Loss: 1.4168, Validation Loss: 1.3524
# Epoch [900/1500], Loss: 1.4155, Validation Loss: 1.3512
# Epoch [1000/1500], Loss: 1.4144, Validation Loss: 1.3500
# Epoch [1100/1500], Loss: 1.4135, Validation Loss: 1.3483
# Epoch [1200/1500], Loss: 1.4126, Validation Loss: 1.3460
# Epoch [1300/1500], Loss: 1.4119, Validation Loss: 1.3435
# Epoch [1400/1500], Loss: 1.4112, Validation Loss: 1.3414
# Epoch [1500/1500], Loss: 1.4105, Validation Loss: 1.3400
# Training complete!
# Trial 17 completed. Results saved.
# Trial 18
# Epoch [100/1500], Loss: 1.5935, Validation Loss: 1.5536
# Epoch [200/1500], Loss: 1.4919, Validation Loss: 1.4347
# Epoch [300/1500], Loss: 1.4569, Validation Loss: 1.3907
# Epoch [400/1500], Loss: 1.4419, Validation Loss: 1.3724
# Epoch [500/1500], Loss: 1.4339, Validation Loss: 1.3624
# Epoch [600/1500], Loss: 1.4287, Validation Loss: 1.3551
# Epoch [700/1500], Loss: 1.4249, Validation Loss: 1.3492
# Epoch [800/1500], Loss: 1.4221, Validation Loss: 1.3456
# Epoch [900/1500], Loss: 1.4199, Validation Loss: 1.3435
# Epoch [1000/1500], Loss: 1.4182, Validation Loss: 1.3418
# Epoch [1100/1500], Loss: 1.4170, Validation Loss: 1.3407
# Epoch [1200/1500], Loss: 1.4161, Validation Loss: 1.3400
# Early stopping at epoch 1277
# Training complete!
# Trial 18 completed. Results saved.
# Trial 19
# Epoch [100/1500], Loss: 1.5963, Validation Loss: 1.5937
# Epoch [200/1500], Loss: 1.4832, Validation Loss: 1.4525
# Epoch [300/1500], Loss: 1.4459, Validation Loss: 1.4093
# Epoch [400/1500], Loss: 1.4314, Validation Loss: 1.3919
# Epoch [500/1500], Loss: 1.4245, Validation Loss: 1.3838
# Epoch [600/1500], Loss: 1.4208, Validation Loss: 1.3793
# Epoch [700/1500], Loss: 1.4184, Validation Loss: 1.3764
# Epoch [800/1500], Loss: 1.4167, Validation Loss: 1.3743
# Epoch [900/1500], Loss: 1.4154, Validation Loss: 1.3725
# Epoch [1000/1500], Loss: 1.4142, Validation Loss: 1.3707
# Epoch [1100/1500], Loss: 1.4132, Validation Loss: 1.3690
# Epoch [1200/1500], Loss: 1.4124, Validation Loss: 1.3676
# Epoch [1300/1500], Loss: 1.4117, Validation Loss: 1.3663
# Epoch [1400/1500], Loss: 1.4111, Validation Loss: 1.3651
# Epoch [1500/1500], Loss: 1.4105, Validation Loss: 1.3641
# Training complete!
# Trial 19 completed. Results saved.
# Trial 20
# Epoch [100/1500], Loss: 1.5983, Validation Loss: 1.6001
# Epoch [200/1500], Loss: 1.4913, Validation Loss: 1.4934
# Epoch [300/1500], Loss: 1.4450, Validation Loss: 1.3862
# Epoch [400/1500], Loss: 1.4283, Validation Loss: 1.3615
# Epoch [500/1500], Loss: 1.4200, Validation Loss: 1.3495
# Epoch [600/1500], Loss: 1.4151, Validation Loss: 1.3427
# Epoch [700/1500], Loss: 1.4120, Validation Loss: 1.3387
# Epoch [800/1500], Loss: 1.4098, Validation Loss: 1.3361
# Epoch [900/1500], Loss: 1.4082, Validation Loss: 1.3348
# Epoch [1000/1500], Loss: 1.4070, Validation Loss: 1.3339
# Epoch [1100/1500], Loss: 1.4059, Validation Loss: 1.3333
# Epoch [1200/1500], Loss: 1.4050, Validation Loss: 1.3329
# Epoch [1300/1500], Loss: 1.4042, Validation Loss: 1.3323
# Epoch [1400/1500], Loss: 1.4036, Validation Loss: 1.3317
# Epoch [1500/1500], Loss: 1.4031, Validation Loss: 1.3312
# Training complete!
# Trial 20 completed. Results saved.
